# %% [markdown]
# # WeatherPy
# #### Python API Homework (python-api-challenge > WeatherPy)  |  by: Shane Gatenby
# ----

# %% [markdown]
# ## Dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
import time
import datetime
from scipy.stats import linregress

# import API keys:
from config import weather_api_key, g_key

# bring in and use citipy to determine city based on latitude and longitude
from citipy import citipy

# set the output csv file & png image output data filepath
# output_data_file = "output_data/cities.csv"
output_data_filepath = "output_data/"

# set the range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate a Cities List

# %%
# create list for holding cities, countries, latitudes, longitudes and weather data
cities = []
countries = []
cities_countries = []
lat_lngs = []

# create set of random latitude/longitude combinations        #### NOTE: UPDATE SIZE BACK TO 1500 ####
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# identify the nearest city for each latitude/longitude combo
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # if the city is unique, then add it to the list: cities
    if city not in cities:
        cities.append(city)
        countries.append(country)
        cities_countries.append([city,country])
        
# print the city count in the list cities to confirm we have a sufficient count
# len(cities)
print(f"The number of random cities in the list is {len(cities_countries)}")
# Out:
# The number of random cities in the list is 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# setup lists to hold data retrieved and inserted from API call
weather_data = []
city_data = []
cloudCover_data = []
country_data = []
date_data = []
humidity_data = []
lat_data = []
lng_data = []
temp_data = []
maxTemp_data = []
windSpeed_data = []

# setup counters, initially set to 1, to count cities with API calls that successfully retrieve data
city_counter = 1
set_of_cities_counter = 1
city_in_set_counter = 1

# setup pieces of API call url/address (base_url and units)
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# perform the API call...fingers crossed, here we go!

# start log for data retrieval from API Call
print("Beginning Data Retrieval")
print("-----------------------------")

# loop through cities & complete API call for each; append weather_data with data when successful
for x in range(len(cities_countries)):
    q_city = cities[x]
    q_city = cities_countries[x][0]
    q_country = cities_countries[x][1]
    query_url = f"{base_url}appid={weather_api_key}&units={units}&q={q_city},{q_country}"
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()

# exception handling for when there is no data returned from the API call
    try:
        print(f"Processing Record {city_counter} ({city_in_set_counter} of set {set_of_cities_counter}) | {weather_json['name']}, {weather_json['sys']['country']}")
        weather_data.append(weather_json)

        # append lists with new data (to be placed in data frame later)
        city_data.append(weather_json["name"])
        country_data.append(weather_json["sys"]["country"])
        cloudCover_data.append(weather_json["clouds"]["all"])
        date_data.append(weather_json["dt"])
        humidity_data.append(weather_json["main"]["humidity"])
        lat_data.append(weather_json["coord"]["lat"])
        lng_data.append(weather_json["coord"]["lon"])
        temp_data.append(weather_json["main"]["temp"])
        maxTemp_data.append(weather_json["main"]["temp_max"])
        windSpeed_data.append(weather_json["wind"]["speed"])

        # update counters
        city_counter += 1
        
        # for set counters, once 50 is reached: reset city_in_set_counter = 1 and add 1 to set_of_cities_counter
        if city_in_set_counter >= 50:
            set_of_cities_counter += 1
            city_in_set_counter = 1
        else:
            city_in_set_counter += 1

    except:
        print(f"Skipping...  City ({q_city}, {q_country}) is not found.")
              
    # end log for data retrieval; print "Data Retrieval Complete" when at the end of the loop
    if x == max(range(len(cities_countries))):
        print("----------------------------")
        print("Data Retrieval Complete")
        print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 (1 of set 1) | Barrow, US
# Processing Record 2 (2 of set 1) | Victoria, SC
# Processing Record 3 (3 of set 1) | Ternate, ID
# Skipping...  City (barentsburg, sj) is not found.
# Processing Record 4 (4 of set 1) | Puerto Ayora, EC
# Processing Record 5 (5 of set 1) | Avarua, CK
# Processing Record 6 (6 of set 1) | Saint-Augustin, CA
# Processing Record 7 (7 of set 1) | Punta Arenas, CL
# Processing Record 8 (8 of set 1) | Luderitz, NA
# Processing Record 9 (9 of set 1) | Aksarka, RU
# Processing Record 10 (10 of set 1) | Kaifeng, CN
# Processing Record 11 (11 of set 1) | Saldanha, ZA
# Processing Record 12 (12 of set 1) | Auki, SB
# Processing Record 13 (13 of set 1) | Morant Bay, JM
# Processing Record 14 (14 of set 1) | New Norfolk, AU
# Processing Record 15 (15 of set 1) | Monrovia, LR
# Skipping...  City (yirol, sd) is not found.
# Processing Record 16 (16 of set 1) | Albany, AU
# Processing Record 17 (17 of set 1) | Karratha, AU
# Processing Record 18 (18 of set 1) | Iqaluit, CA
# Processing Record 19 (19 of set 1) | Kamaishi, JP
# Processing Record 20 (20 of set 1) | Inongo, CD
# Processing Record 21 (21 of set 1) | Hobart, AU
# Processing Record 22 (22 of set 1) | Abonnema, NG
# Processing Record 23 (23 of set 1) | Cidreira, BR
# Skipping...  City (mataura, pf) is not found.
# Processing Record 24 (24 of set 1) | Nailon, PH
# Processing Record 25 (25 of set 1) | Fortuna, US
# Processing Record 26 (26 of set 1) | Faanui, PF
# Processing Record 27 (27 of set 1) | Ushuaia, AR
# Skipping...  City (toulepleu, ci) is not found.
# Processing Record 28 (28 of set 1) | Grandola, PT
# Skipping...  City (bokspits, bw) is not found.
# Skipping...  City (illoqqortoormiut, gl) is not found.
# Processing Record 29 (29 of set 1) | Fuyang, CN
# Processing Record 30 (30 of set 1) | Rikitea, PF
# Processing Record 31 (31 of set 1) | Norman Wells, CA
# Processing Record 32 (32 of set 1) | La Tuque, CA
# Processing Record 33 (33 of set 1) | Busselton, AU
# Processing Record 34 (34 of set 1) | Sana, PE
# Processing Record 35 (35 of set 1) | Vaini, TO
# Processing Record 36 (36 of set 1) | Evensk, RU
# Processing Record 37 (37 of set 1) | Jamestown, SH
# Processing Record 38 (38 of set 1) | Kautokeino, NO
# Processing Record 39 (39 of set 1) | Petropavlovsk-Kamchatsky, RU
# Processing Record 40 (40 of set 1) | Bluff, NZ
# Processing Record 41 (41 of set 1) | Margate, ZA
# Processing Record 42 (42 of set 1) | Cherskiy, RU
# Processing Record 43 (43 of set 1) | Mirny, RU
# Processing Record 44 (44 of set 1) | Yumen, CN
# Processing Record 45 (45 of set 1) | Rio Gallegos, AR
# Processing Record 46 (46 of set 1) | Butaritari, KI
# Processing Record 47 (47 of set 1) | Atuona, PF
# Processing Record 48 (48 of set 1) | Chokurdakh, RU
# Processing Record 49 (49 of set 1) | Los Llanos de Aridane, ES
# Processing Record 50 (50 of set 1) | Hermanus, ZA
# Processing Record 51 (1 of set 2) | Ribeira Grande, PT
# Processing Record 52 (2 of set 2) | Hilo, US
# Processing Record 53 (3 of set 2) | Mendi, ET
# Processing Record 54 (4 of set 2) | Bethel, US
# Processing Record 55 (5 of set 2) | Cape Town, ZA
# Skipping...  City (abu samrah, qa) is not found.
# Processing Record 56 (6 of set 2) | Tessalit, ML
# Skipping...  City (lolua, tv) is not found.
# Processing Record 57 (7 of set 2) | Thaton, MM
# Processing Record 58 (8 of set 2) | Kuusamo, FI
# Processing Record 59 (9 of set 2) | Esperance, AU
# Processing Record 60 (10 of set 2) | General Roca, AR
# Processing Record 61 (11 of set 2) | Sangar, RU
# Processing Record 62 (12 of set 2) | College, US
# Processing Record 63 (13 of set 2) | Acapulco de Juarez, MX
# Processing Record 64 (14 of set 2) | Porbandar, IN
# Processing Record 65 (15 of set 2) | Georgetown, SH
# Processing Record 66 (16 of set 2) | Chui, UY
# Processing Record 67 (17 of set 2) | Bambous Virieux, MU
# Processing Record 68 (18 of set 2) | Arrondissement de Villefranche-de-Rouergue, FR
# Processing Record 69 (19 of set 2) | Mar del Plata, AR
# Processing Record 70 (20 of set 2) | Villa Juarez, MX
# Processing Record 71 (21 of set 2) | Bud, NO
# Skipping...  City (jarjis, tn) is not found.
# Processing Record 72 (22 of set 2) | Alofi, NU
# Processing Record 73 (23 of set 2) | Coquimbo, CL
# Processing Record 74 (24 of set 2) | Torbay, CA
# Processing Record 75 (25 of set 2) | Finschhafen, PG
# Processing Record 76 (26 of set 2) | Coyhaique, CL
# Processing Record 77 (27 of set 2) | Te Anau, NZ
# Processing Record 78 (28 of set 2) | Pevek, RU
# Processing Record 79 (29 of set 2) | Upernavik, GL
# Skipping...  City (oga, jp) is not found.
# Processing Record 80 (30 of set 2) | Lebu, CL
# Processing Record 81 (31 of set 2) | Manzhouli, CN
# Processing Record 82 (32 of set 2) | Kapaa, US
# Skipping...  City (tsihombe, mg) is not found.
# Processing Record 83 (33 of set 2) | Havelock, US
# Processing Record 84 (34 of set 2) | Elizabeth City, US
# Processing Record 85 (35 of set 2) | Peleduy, RU
# Processing Record 86 (36 of set 2) | Itarema, BR
# Processing Record 87 (37 of set 2) | Paka, MY
# Processing Record 88 (38 of set 2) | Saint-Philippe, RE
# Processing Record 89 (39 of set 2) | Akdepe, TM
# Processing Record 90 (40 of set 2) | Provideniya, RU
# Processing Record 91 (41 of set 2) | Khatassy, RU
# Processing Record 92 (42 of set 2) | Iwaki, JP
# Processing Record 93 (43 of set 2) | Salalah, OM
# Skipping...  City (codrington, ag) is not found.
# Processing Record 94 (44 of set 2) | Dombarovskiy, RU
# Processing Record 95 (45 of set 2) | Wembley, CA
# Processing Record 96 (46 of set 2) | Itamaraju, BR
# Processing Record 97 (47 of set 2) | Mahebourg, MU
# Processing Record 98 (48 of set 2) | Bredasdorp, ZA
# Processing Record 99 (49 of set 2) | Lompoc, US
# Processing Record 100 (50 of set 2) | Longyearbyen, SJ
# Processing Record 101 (1 of set 3) | Mossamedes, AO
# Processing Record 102 (2 of set 3) | Saint-Pierre, PM
# Processing Record 103 (3 of set 3) | Lubango, AO
# Processing Record 104 (4 of set 3) | Lagoa, PT
# Processing Record 105 (5 of set 3) | Qaanaaq, GL
# Processing Record 106 (6 of set 3) | Rafai, CF
# Processing Record 107 (7 of set 3) | Nikolskoye, RU
# Processing Record 108 (8 of set 3) | Port Elizabeth, ZA
# Skipping...  City (taolanaro, mg) is not found.
# Processing Record 109 (9 of set 3) | Tefe, BR
# Processing Record 110 (10 of set 3) | Beroroha, MG
# Processing Record 111 (11 of set 3) | Hithadhoo, MV
# Processing Record 112 (12 of set 3) | Carnarvon, AU
# Skipping...  City (marcona, pe) is not found.
# Processing Record 113 (13 of set 3) | Vrangel, RU
# Skipping...  City (grand river south east, mu) is not found.
# Processing Record 114 (14 of set 3) | Pelym, RU
# Skipping...  City (taburao, ki) is not found.
# Skipping...  City (nizhneyansk, ru) is not found.
# Skipping...  City (saleaula, ws) is not found.
# Processing Record 115 (15 of set 3) | Tautira, PF
# Processing Record 116 (16 of set 3) | Paamiut, GL
# Processing Record 117 (17 of set 3) | Manzanillo, MX
# Processing Record 118 (18 of set 3) | Tasiilaq, GL
# Skipping...  City (palabuhanratu, id) is not found.
# Processing Record 119 (19 of set 3) | Semey, KZ
# Processing Record 120 (20 of set 3) | Saint George, BM
# Processing Record 121 (21 of set 3) | Escada, BR
# Processing Record 122 (22 of set 3) | Acatic, MX
# Processing Record 123 (23 of set 3) | Ponta do Sol, CV
# Processing Record 124 (24 of set 3) | Wladyslawowo, PL
# Processing Record 125 (25 of set 3) | Kavieng, PG
# Processing Record 126 (26 of set 3) | Yellowknife, CA
# Processing Record 127 (27 of set 3) | Lavrentiya, RU
# Processing Record 128 (28 of set 3) | Vanimo, PG
# Processing Record 129 (29 of set 3) | Souillac, MU
# Processing Record 130 (30 of set 3) | Santa Ines, BR
# Processing Record 131 (31 of set 3) | Emerald, AU
# Processing Record 132 (32 of set 3) | Port Hardy, CA
# Processing Record 133 (33 of set 3) | Nuuk, GL
# Skipping...  City (samusu, ws) is not found.
# Skipping...  City (meyungs, pw) is not found.
# Processing Record 134 (34 of set 3) | Kaitangata, NZ
# Skipping...  City (belushya guba, ru) is not found.
# Processing Record 135 (35 of set 3) | Talara, PE
# Processing Record 136 (36 of set 3) | Cockburn Town, BS
# Processing Record 137 (37 of set 3) | Villa Carlos Paz, AR
# Processing Record 138 (38 of set 3) | Saint-Georges, GF
# Processing Record 139 (39 of set 3) | Lokosovo, RU
# Processing Record 140 (40 of set 3) | Medvedevo, RU
# Processing Record 141 (41 of set 3) | Flinders, AU
# Processing Record 142 (42 of set 3) | Khatanga, RU
# Processing Record 143 (43 of set 3) | Bahia Blanca, AR
# Processing Record 144 (44 of set 3) | Caravelas, BR
# Skipping...  City (ye, mm) is not found.
# Processing Record 145 (45 of set 3) | Hoima, UG
# Processing Record 146 (46 of set 3) | Dikson, RU
# Processing Record 147 (47 of set 3) | Malaryta, BY
# Processing Record 148 (48 of set 3) | Hasaki, JP
# Processing Record 149 (49 of set 3) | Saskylakh, RU
# Skipping...  City (umzimvubu, za) is not found.
# Processing Record 150 (50 of set 3) | Arraial do Cabo, BR
# Processing Record 151 (1 of set 4) | Lida, BY
# Processing Record 152 (2 of set 4) | Aykhal, RU
# Processing Record 153 (3 of set 4) | Baharly, TM
# Processing Record 154 (4 of set 4) | Nar'yan-Mar, RU
# Processing Record 155 (5 of set 4) | Alta Floresta, BR
# Processing Record 156 (6 of set 4) | Alyth, GB
# Processing Record 157 (7 of set 4) | Broome, AU
# Processing Record 158 (8 of set 4) | Carndonagh, IE
# Skipping...  City (attawapiskat, ca) is not found.
# Processing Record 159 (9 of set 4) | Normandin, CA
# Processing Record 160 (10 of set 4) | Manta, EC
# Processing Record 161 (11 of set 4) | Srednekolymsk, RU
# Processing Record 162 (12 of set 4) | Yerbogachen, RU
# Processing Record 163 (13 of set 4) | Merowe, SD
# Processing Record 164 (14 of set 4) | Kurchum, KZ
# Processing Record 165 (15 of set 4) | Ngunguru, NZ
# Processing Record 166 (16 of set 4) | Cabo San Lucas, MX
# Processing Record 167 (17 of set 4) | Vestmannaeyjar, IS
# Processing Record 168 (18 of set 4) | Guarapari, BR
# Processing Record 169 (19 of set 4) | Usinsk, RU
# Processing Record 170 (20 of set 4) | Marquette, US
# Processing Record 171 (21 of set 4) | Tuktoyaktuk, CA
# Processing Record 172 (22 of set 4) | Pyapon, MM
# Processing Record 173 (23 of set 4) | Port Hedland, AU
# Processing Record 174 (24 of set 4) | Butka, RU
# Skipping...  City (kyle of lochalsh, gb) is not found.
# Processing Record 175 (25 of set 4) | Comodoro Rivadavia, AR
# Processing Record 176 (26 of set 4) | Sangamner, IN
# Skipping...  City (chagda, ru) is not found.
# Skipping...  City (vaitupu, wf) is not found.
# Processing Record 177 (27 of set 4) | Talnakh, RU
# Processing Record 178 (28 of set 4) | Oriximina, BR
# Processing Record 179 (29 of set 4) | Batticaloa, LK
# Processing Record 180 (30 of set 4) | Rantepao, ID
# Processing Record 181 (31 of set 4) | Durusu, TR
# Processing Record 182 (32 of set 4) | Teya, RU
# Processing Record 183 (33 of set 4) | Wald-Michelbach, DE
# Processing Record 184 (34 of set 4) | Ugoofaaru, MV
# Processing Record 185 (35 of set 4) | Tuatapere, NZ
# Processing Record 186 (36 of set 4) | Port Alfred, ZA
# Processing Record 187 (37 of set 4) | Sao Joao da Barra, BR
# Processing Record 188 (38 of set 4) | Korla, CN
# Processing Record 189 (39 of set 4) | Pisco, PE
# Processing Record 190 (40 of set 4) | Castro, CL
# Processing Record 191 (41 of set 4) | Tarabuco, BO
# Processing Record 192 (42 of set 4) | Santa Rosa, BO
# Processing Record 193 (43 of set 4) | Tukrah, LY
# Processing Record 194 (44 of set 4) | Tilichiki, RU
# Processing Record 195 (45 of set 4) | Aklavik, CA
# Processing Record 196 (46 of set 4) | Turkan, AZ
# Processing Record 197 (47 of set 4) | Yar-Sale, RU
# Processing Record 198 (48 of set 4) | Tonantins, BR
# Processing Record 199 (49 of set 4) | Zhigansk, RU
# Skipping...  City (faya, td) is not found.
# Processing Record 200 (50 of set 4) | Kodiak, US
# Processing Record 201 (1 of set 5) | Manoel Urbano, BR
# Processing Record 202 (2 of set 5) | Horta, PT
# Processing Record 203 (3 of set 5) | Mersing, MY
# Processing Record 204 (4 of set 5) | Santa Maria do Suacui, BR
# Processing Record 205 (5 of set 5) | Caala, AO
# Processing Record 206 (6 of set 5) | Porto Novo, CV
# Processing Record 207 (7 of set 5) | Chu, KZ
# Skipping...  City (sentyabrskiy, ru) is not found.
# Processing Record 208 (8 of set 5) | Sheltozero, RU
# Processing Record 209 (9 of set 5) | Vao, NC
# Processing Record 210 (10 of set 5) | Verkhoyansk, RU
# Processing Record 211 (11 of set 5) | Acarau, BR
# Processing Record 212 (12 of set 5) | Cururupu, BR
# Processing Record 213 (13 of set 5) | Ecublens, CH
# Skipping...  City (birin, dz) is not found.
# Processing Record 214 (14 of set 5) | Kapit, MY
# Processing Record 215 (15 of set 5) | Ryotsu, JP
# Processing Record 216 (16 of set 5) | Sukumo, JP
# Processing Record 217 (17 of set 5) | Haines Junction, CA
# Processing Record 218 (18 of set 5) | Thompson, CA
# Processing Record 219 (19 of set 5) | Muravlenko, RU
# Processing Record 220 (20 of set 5) | Manicore, BR
# Processing Record 221 (21 of set 5) | Grenville, GD
# Processing Record 222 (22 of set 5) | Tambopata, PE
# Processing Record 223 (23 of set 5) | Nome, US
# Processing Record 224 (24 of set 5) | Skibbereen, IE
# Skipping...  City (tumannyy, ru) is not found.
# Processing Record 225 (25 of set 5) | Wahpeton, US
# Processing Record 226 (26 of set 5) | Sur, OM
# Processing Record 227 (27 of set 5) | Tiksi, RU
# Skipping...  City (mullaitivu, lk) is not found.
# Processing Record 228 (28 of set 5) | Vila Franca do Campo, PT
# Processing Record 229 (29 of set 5) | Mezhova, UA
# Processing Record 230 (30 of set 5) | Kintampo, GH
# Processing Record 231 (31 of set 5) | Bela, PK
# Processing Record 232 (32 of set 5) | Nyurba, RU
# Processing Record 233 (33 of set 5) | Coxim, BR
# Processing Record 234 (34 of set 5) | Vazante, BR
# Skipping...  City (mys shmidta, ru) is not found.
# Processing Record 235 (35 of set 5) | Juliaca, PE
# Processing Record 236 (36 of set 5) | Nemuro, JP
# Processing Record 237 (37 of set 5) | Eyl, SO
# Processing Record 238 (38 of set 5) | Chulman, RU
# Processing Record 239 (39 of set 5) | Bambanglipuro, ID
# Processing Record 240 (40 of set 5) | Mackay, AU
# Skipping...  City (macaboboni, ph) is not found.
# Processing Record 241 (41 of set 5) | Kathmandu, NP
# Processing Record 242 (42 of set 5) | Tapes, BR
# Processing Record 243 (43 of set 5) | Boa Vista, BR
# Processing Record 244 (44 of set 5) | Kutum, SD
# Processing Record 245 (45 of set 5) | Susanville, US
# Processing Record 246 (46 of set 5) | Sandwick, GB
# Processing Record 247 (47 of set 5) | Komsomolskiy, RU
# Processing Record 248 (48 of set 5) | Baruun-Urt, MN
# Processing Record 249 (49 of set 5) | Los Alamos, US
# Processing Record 250 (50 of set 5) | East London, ZA
# Processing Record 251 (1 of set 6) | Vostok, RU
# Processing Record 252 (2 of set 6) | Portland, AU
# Processing Record 253 (3 of set 6) | Mehran, IR
# Processing Record 254 (4 of set 6) | Buala, SB
# Processing Record 255 (5 of set 6) | Tekeli, KZ
# Processing Record 256 (6 of set 6) | Nacala, MZ
# Processing Record 257 (7 of set 6) | Jiamusi, CN
# Processing Record 258 (8 of set 6) | Alpena, US
# Processing Record 259 (9 of set 6) | Domoni, KM
# Processing Record 260 (10 of set 6) | Lorengau, PG
# Processing Record 261 (11 of set 6) | Staryy Nadym, RU
# Processing Record 262 (12 of set 6) | Balabac, PH
# Processing Record 263 (13 of set 6) | Aquiraz, BR
# Processing Record 264 (14 of set 6) | Taseyevo, RU
# Processing Record 265 (15 of set 6) | Hobyo, SO
# Skipping...  City (airai, pw) is not found.
# Processing Record 266 (16 of set 6) | Dwarka, IN
# Processing Record 267 (17 of set 6) | Vila Velha, BR
# Processing Record 268 (18 of set 6) | Grindavik, IS
# Processing Record 269 (19 of set 6) | Lucapa, AO
# Processing Record 270 (20 of set 6) | Arrondissement de Mont-de-Marsan, FR
# Skipping...  City (wulanhaote, cn) is not found.
# Processing Record 271 (21 of set 6) | Jalu, LY
# Processing Record 272 (22 of set 6) | Husavik, IS
# Processing Record 273 (23 of set 6) | Orlik, RU
# Processing Record 274 (24 of set 6) | Port Lincoln, AU
# Processing Record 275 (25 of set 6) | Antalaha, MG
# Processing Record 276 (26 of set 6) | Adrar, DZ
# Processing Record 277 (27 of set 6) | Kununurra, AU
# Processing Record 278 (28 of set 6) | Beringovskiy, RU
# Processing Record 279 (29 of set 6) | Poum, NC
# Processing Record 280 (30 of set 6) | Gravdal, NO
# Processing Record 281 (31 of set 6) | San Ramon, BO
# Skipping...  City (boljarovo, bg) is not found.
# Processing Record 282 (32 of set 6) | Omsukchan, RU
# Processing Record 283 (33 of set 6) | Narsaq, GL
# Processing Record 284 (34 of set 6) | La Asuncion, VE
# Processing Record 285 (35 of set 6) | Severo-Kuril'sk, RU
# Processing Record 286 (36 of set 6) | Monterey, US
# Processing Record 287 (37 of set 6) | Batsfjord, NO
# Processing Record 288 (38 of set 6) | Hambantota, LK
# Processing Record 289 (39 of set 6) | Rawson, AR
# Processing Record 290 (40 of set 6) | Ciudad de Armeria, MX
# Skipping...  City (malwan, in) is not found.
# Processing Record 291 (41 of set 6) | Rurrenabaque, BO
# Skipping...  City (ngukurr, au) is not found.
# Processing Record 292 (42 of set 6) | Ilulissat, GL
# Processing Record 293 (43 of set 6) | Kumul, CN
# Processing Record 294 (44 of set 6) | Caucaia, BR
# Processing Record 295 (45 of set 6) | Erenhot, CN
# Processing Record 296 (46 of set 6) | Kysyl-Syr, RU
# Processing Record 297 (47 of set 6) | Bulungu, CD
# Processing Record 298 (48 of set 6) | Raudeberg, NO
# Processing Record 299 (49 of set 6) | Geraldton, AU
# Processing Record 300 (50 of set 6) | Rhodes, GR
# Processing Record 301 (1 of set 7) | Mayna, RU
# Processing Record 302 (2 of set 7) | Melfi, TD
# Skipping...  City (asau, tv) is not found.
# Processing Record 303 (3 of set 7) | Vardo, NO
# Skipping...  City (yomitan, jp) is not found.
# Processing Record 304 (4 of set 7) | Alice Springs, AU
# Processing Record 305 (5 of set 7) | Tres Arroyos, AR
# Processing Record 306 (6 of set 7) | Tsimmerbude, RU
# Skipping...  City (saint anthony, ca) is not found.
# Processing Record 307 (7 of set 7) | Fairbanks, US
# Processing Record 308 (8 of set 7) | Hervey Bay, AU
# Processing Record 309 (9 of set 7) | Kavaratti, IN
# Processing Record 310 (10 of set 7) | Taoudenni, ML
# Processing Record 311 (11 of set 7) | Dafeng, CN
# Processing Record 312 (12 of set 7) | Brae, GB
# Processing Record 313 (13 of set 7) | Litovko, RU
# Processing Record 314 (14 of set 7) | Soponya, HU
# Processing Record 315 (15 of set 7) | Saint-Joseph, RE
# Processing Record 316 (16 of set 7) | Roma, AU
# Processing Record 317 (17 of set 7) | Moron, MN
# Processing Record 318 (18 of set 7) | Goya, AR
# Processing Record 319 (19 of set 7) | Manado, ID
# Skipping...  City (babanusah, sd) is not found.
# Processing Record 320 (20 of set 7) | Bokoro, TD
# Processing Record 321 (21 of set 7) | Karnal, IN
# Processing Record 322 (22 of set 7) | Copiapo, CL
# Processing Record 323 (23 of set 7) | Safi, MA
# Processing Record 324 (24 of set 7) | Visby, SE
# Processing Record 325 (25 of set 7) | Constitucion, MX
# Processing Record 326 (26 of set 7) | Makakilo City, US
# Processing Record 327 (27 of set 7) | San Sebastian, CO
# Processing Record 328 (28 of set 7) | Nara, ML
# Processing Record 329 (29 of set 7) | Inverell, AU
# Processing Record 330 (30 of set 7) | Borogontsy, RU
# Processing Record 331 (31 of set 7) | Izmir, TR
# Processing Record 332 (32 of set 7) | Vila do Maio, CV
# Processing Record 333 (33 of set 7) | Lundazi, ZM
# Processing Record 334 (34 of set 7) | Bhainsa, IN
# Processing Record 335 (35 of set 7) | Schio, IT
# Processing Record 336 (36 of set 7) | Clyde River, CA
# Processing Record 337 (37 of set 7) | Novyy Urengoy, RU
# Processing Record 338 (38 of set 7) | Songjianghe, CN
# Processing Record 339 (39 of set 7) | Aracoiaba, BR
# Processing Record 340 (40 of set 7) | Williams Lake, CA
# Processing Record 341 (41 of set 7) | Dalvik, IS
# Processing Record 342 (42 of set 7) | Krasnosel'kup, RU
# Skipping...  City (haibowan, cn) is not found.
# Processing Record 343 (43 of set 7) | Sola, VU
# Processing Record 344 (44 of set 7) | Zyryanka, RU
# Processing Record 345 (45 of set 7) | Yulara, AU
# Processing Record 346 (46 of set 7) | Tura, RU
# Processing Record 347 (47 of set 7) | Gordeyevka, RU
# Processing Record 348 (48 of set 7) | Havre-Saint-Pierre, CA
# Processing Record 349 (49 of set 7) | Sitka, US
# Processing Record 350 (50 of set 7) | Wenceslau Braz, BR
# Processing Record 351 (1 of set 8) | Shalinskoye, RU
# Processing Record 352 (2 of set 8) | Bitlis, TR
# Processing Record 353 (3 of set 8) | Yatou, CN
# Processing Record 354 (4 of set 8) | Cayenne, GF
# Processing Record 355 (5 of set 8) | Shimoda, JP
# Processing Record 356 (6 of set 8) | Pingliang, CN
# Processing Record 357 (7 of set 8) | Conde, BR
# Processing Record 358 (8 of set 8) | Praya, ID
# Processing Record 359 (9 of set 8) | High Prairie, CA
# Processing Record 360 (10 of set 8) | Bonavista, CA
# Processing Record 361 (11 of set 8) | Kimbe, PG
# Processing Record 362 (12 of set 8) | Amga, RU
# Processing Record 363 (13 of set 8) | Opportunity, US
# Processing Record 364 (14 of set 8) | Hamilton, BM
# Skipping...  City (tabulbah, tn) is not found.
# Processing Record 365 (15 of set 8) | Kieta, PG
# Processing Record 366 (16 of set 8) | Metro, ID
# Processing Record 367 (17 of set 8) | Sao Gabriel da Cachoeira, BR
# Processing Record 368 (18 of set 8) | Huilong, CN
# Processing Record 369 (19 of set 8) | Izumo, JP
# Processing Record 370 (20 of set 8) | Jumla, NP
# Processing Record 371 (21 of set 8) | Bowen, AU
# Processing Record 372 (22 of set 8) | Legionowo, PL
# Processing Record 373 (23 of set 8) | Ha Tinh, VN
# Processing Record 374 (24 of set 8) | Esmeraldas, EC
# Processing Record 375 (25 of set 8) | Gornopravdinsk, RU
# Processing Record 376 (26 of set 8) | Trelaze, FR
# Processing Record 377 (27 of set 8) | Nuevitas, CU
# Processing Record 378 (28 of set 8) | Rio Brilhante, BR
# Processing Record 379 (29 of set 8) | OErnskoeldsvik, SE
# Processing Record 380 (30 of set 8) | Ancud, CL
# Processing Record 381 (31 of set 8) | Natal, BR
# Processing Record 382 (32 of set 8) | Jiblah, YE
# Processing Record 383 (33 of set 8) | Sarab, IR
# Processing Record 384 (34 of set 8) | Djambala, CG
# Processing Record 385 (35 of set 8) | Saint-Honore, CA
# Processing Record 386 (36 of set 8) | Ambovombe, MG
# Processing Record 387 (37 of set 8) | La Ronge, CA
# Processing Record 388 (38 of set 8) | Grand Gaube, MU
# Processing Record 389 (39 of set 8) | Naze, JP
# Processing Record 390 (40 of set 8) | Troitskoye, RU
# Processing Record 391 (41 of set 8) | Batemans Bay, AU
# Skipping...  City (sug-aksy, ru) is not found.
# Skipping...  City (grand centre, ca) is not found.
# Processing Record 392 (42 of set 8) | Sao Filipe, CV
# Processing Record 393 (43 of set 8) | Luanda, AO
# Processing Record 394 (44 of set 8) | Westport, IE
# Processing Record 395 (45 of set 8) | Santiago, PY
# Processing Record 396 (46 of set 8) | Birjand, IR
# Processing Record 397 (47 of set 8) | Xichang, CN
# Processing Record 398 (48 of set 8) | Port Blair, IN
# Processing Record 399 (49 of set 8) | Gayeri, BF
# Processing Record 400 (50 of set 8) | Nakusp, CA
# Processing Record 401 (1 of set 9) | Arrondissement de Bar-le-Duc, FR
# Skipping...  City (amderma, ru) is not found.
# Processing Record 402 (2 of set 9) | Ormara, PK
# Processing Record 403 (3 of set 9) | Weinan, CN
# Processing Record 404 (4 of set 9) | Mahajanga, MG
# Processing Record 405 (5 of set 9) | Oistins, BB
# Processing Record 406 (6 of set 9) | Tolaga Bay, NZ
# Processing Record 407 (7 of set 9) | Vaitape, PF
# Processing Record 408 (8 of set 9) | Pishin, PK
# Processing Record 409 (9 of set 9) | Port Moresby, PG
# Processing Record 410 (10 of set 9) | Werda, BW
# Processing Record 411 (11 of set 9) | Prince Rupert, CA
# Processing Record 412 (12 of set 9) | Mandalgovi, MN
# Processing Record 413 (13 of set 9) | Bengkulu, ID
# Processing Record 414 (14 of set 9) | Walvis Bay, NA
# Processing Record 415 (15 of set 9) | Itaituba, BR
# Processing Record 416 (16 of set 9) | Casselman, CA
# Processing Record 417 (17 of set 9) | 'Ahuimanu, US
# Processing Record 418 (18 of set 9) | Richards Bay, ZA
# Processing Record 419 (19 of set 9) | Ajuchitlan, MX
# Skipping...  City (avera, pf) is not found.
# Processing Record 420 (20 of set 9) | Severobaykalsk, RU
# Processing Record 421 (21 of set 9) | Mwinilunga, ZM
# Processing Record 422 (22 of set 9) | Dryden, CA
# Processing Record 423 (23 of set 9) | Nizwa, OM
# Processing Record 424 (24 of set 9) | Emba, KZ
# Processing Record 425 (25 of set 9) | Taber, CA
# Processing Record 426 (26 of set 9) | Lakselv, NO
# Processing Record 427 (27 of set 9) | Porto Santo, PT
# Skipping...  City (lata, sb) is not found.
# Processing Record 428 (28 of set 9) | Linqiong, CN
# Skipping...  City (vastervik, se) is not found.
# Processing Record 429 (29 of set 9) | Gondanglegi, ID
# Processing Record 430 (30 of set 9) | Viseu, BR
# Processing Record 431 (31 of set 9) | Labuhan, ID
# Processing Record 432 (32 of set 9) | Salinas, MX
# Skipping...  City (gogrial, sd) is not found.
# Processing Record 433 (33 of set 9) | Marsassoum, SN
# Processing Record 434 (34 of set 9) | Padang, ID
# Processing Record 435 (35 of set 9) | Burns Lake, CA
# Processing Record 436 (36 of set 9) | Norman, US
# Processing Record 437 (37 of set 9) | Bluefield, US
# Skipping...  City (kemijarvi, fi) is not found.
# Processing Record 438 (38 of set 9) | Chimoio, MZ
# Processing Record 439 (39 of set 9) | Carballo, ES
# Processing Record 440 (40 of set 9) | Eureka, US
# Processing Record 441 (41 of set 9) | Changde, CN
# Processing Record 442 (42 of set 9) | Samoded, RU
# Processing Record 443 (43 of set 9) | Svetlogorsk, RU
# Processing Record 444 (44 of set 9) | San Quintin, MX
# Skipping...  City (goderich, sl) is not found.
# Processing Record 445 (45 of set 9) | Assiut, EG
# Processing Record 446 (46 of set 9) | Jacqueville, CI
# Processing Record 447 (47 of set 9) | Shelburne, CA
# Processing Record 448 (48 of set 9) | Ossora, RU
# Processing Record 449 (49 of set 9) | Isangel, VU
# Processing Record 450 (50 of set 9) | Mogadishu, SO
# Processing Record 451 (1 of set 10) | Terrace, CA
# Skipping...  City (haapu, pf) is not found.
# Skipping...  City (warqla, dz) is not found.
# Processing Record 452 (2 of set 10) | Northam, AU
# Processing Record 453 (3 of set 10) | Tigil, RU
# Processing Record 454 (4 of set 10) | Roald, NO
# Processing Record 455 (5 of set 10) | Idanre, NG
# Processing Record 456 (6 of set 10) | Tutoia, BR
# Processing Record 457 (7 of set 10) | Belmonte, BR
# Processing Record 458 (8 of set 10) | Andenes, NO
# Processing Record 459 (9 of set 10) | Pochutla, MX
# Processing Record 460 (10 of set 10) | Bojnourd, IR
# Processing Record 461 (11 of set 10) | Gulabpura, IN
# Processing Record 462 (12 of set 10) | Leh, IN
# Processing Record 463 (13 of set 10) | Kaeo, NZ
# Processing Record 464 (14 of set 10) | Port Macquarie, AU
# Processing Record 465 (15 of set 10) | Sakakah, SA
# Processing Record 466 (16 of set 10) | Tongzi, CN
# Processing Record 467 (17 of set 10) | Zheleznodorozhnyy, RU
# Processing Record 468 (18 of set 10) | Esim, GH
# Processing Record 469 (19 of set 10) | Omboue, GA
# Processing Record 470 (20 of set 10) | Devils Lake, US
# Processing Record 471 (21 of set 10) | Hoshcha, UA
# Processing Record 472 (22 of set 10) | Salamanca, ES
# Processing Record 473 (23 of set 10) | Coahuayana Viejo, MX
# Processing Record 474 (24 of set 10) | Stepnoye, RU
# Processing Record 475 (25 of set 10) | Torbat-e Jam, IR
# Processing Record 476 (26 of set 10) | Morondava, MG
# Processing Record 477 (27 of set 10) | Beyneu, KZ
# Processing Record 478 (28 of set 10) | Ati, TD
# Processing Record 479 (29 of set 10) | Carutapera, BR
# Processing Record 480 (30 of set 10) | Mayo, CA
# Processing Record 481 (31 of set 10) | Nanortalik, GL
# Processing Record 482 (32 of set 10) | Umm Lajj, SA
# Processing Record 483 (33 of set 10) | Juneau, US
# Processing Record 484 (34 of set 10) | Mahon, ES
# Processing Record 485 (35 of set 10) | Tabuk, SA
# Processing Record 486 (36 of set 10) | Bom Jesus, BR
# Processing Record 487 (37 of set 10) | Biltine, TD
# Skipping...  City (anar darreh, af) is not found.
# Processing Record 488 (38 of set 10) | Minna, NG
# Processing Record 489 (39 of set 10) | Cabra, PH
# Processing Record 490 (40 of set 10) | Kruisfontein, ZA
# Processing Record 491 (41 of set 10) | Neiafu, TO
# Processing Record 492 (42 of set 10) | Houston, CA
# Skipping...  City (doha, kw) is not found.
# Processing Record 493 (43 of set 10) | Lethem, GY
# Processing Record 494 (44 of set 10) | Ouegoa, NC
# Processing Record 495 (45 of set 10) | Humberto de Campos, BR
# Processing Record 496 (46 of set 10) | Kostomuksha, RU
# Skipping...  City (toliary, mg) is not found.
# Processing Record 497 (47 of set 10) | Chantada, ES
# Processing Record 498 (48 of set 10) | Kulykiv, UA
# Skipping...  City (vila, vu) is not found.
# Processing Record 499 (49 of set 10) | Dingle, IE
# Processing Record 500 (50 of set 10) | Eyemouth, GB
# Processing Record 501 (1 of set 11) | Sullana, PE
# Processing Record 502 (2 of set 11) | Mecca, SA
# Processing Record 503 (3 of set 11) | Pamplona, ES
# Processing Record 504 (4 of set 11) | Russell, NZ
# Processing Record 505 (5 of set 11) | Magadan, RU
# Processing Record 506 (6 of set 11) | Puerto del Rosario, ES
# Processing Record 507 (7 of set 11) | Palmer, US
# Processing Record 508 (8 of set 11) | Necochea, AR
# Processing Record 509 (9 of set 11) | Turaif, SA
# Processing Record 510 (10 of set 11) | Khasan, RU
# Processing Record 511 (11 of set 11) | Nixa, US
# Processing Record 512 (12 of set 11) | Bakchar, RU
# Skipping...  City (bur gabo, so) is not found.
# Processing Record 513 (13 of set 11) | Leningradskiy, RU
# Processing Record 514 (14 of set 11) | Zhoucheng, CN
# Processing Record 515 (15 of set 11) | Springdale, CA
# Processing Record 516 (16 of set 11) | Zaraza, VE
# Processing Record 517 (17 of set 11) | Ostrovnoy, RU
# Processing Record 518 (18 of set 11) | Mosquera, CO
# Processing Record 519 (19 of set 11) | Balikpapan, ID
# Processing Record 520 (20 of set 11) | Basco, PH
# Processing Record 521 (21 of set 11) | San Patricio, MX
# Processing Record 522 (22 of set 11) | Hanzhong, CN
# Processing Record 523 (23 of set 11) | Yurimaguas, PE
# Processing Record 524 (24 of set 11) | Merauke, ID
# Processing Record 525 (25 of set 11) | Garoowe, SO
# Processing Record 526 (26 of set 11) | Mazamari, PE
# Processing Record 527 (27 of set 11) | Grand Forks, US
# Processing Record 528 (28 of set 11) | Altagracia de Orituco, VE
# Processing Record 529 (29 of set 11) | Mbarara, UG
# Processing Record 530 (30 of set 11) | Saint-Francois, GP
# Processing Record 531 (31 of set 11) | Boende, CD
# Processing Record 532 (32 of set 11) | Sorland, NO
# Processing Record 533 (33 of set 11) | Qiongshan, CN
# Processing Record 534 (34 of set 11) | Bubaque, GW
# Processing Record 535 (35 of set 11) | Wajima, JP
# Processing Record 536 (36 of set 11) | Australind, AU
# Processing Record 537 (37 of set 11) | Ninh Binh, VN
# Processing Record 538 (38 of set 11) | Fort Nelson, CA
# Skipping...  City (kibala, ao) is not found.
# Processing Record 539 (39 of set 11) | Bathsheba, BB
# Processing Record 540 (40 of set 11) | Sarakhs, IR
# Skipping...  City (skalistyy, ru) is not found.
# Processing Record 541 (41 of set 11) | Okhotsk, RU
# Processing Record 542 (42 of set 11) | Gawler, AU
# Processing Record 543 (43 of set 11) | Pemangkat, ID
# Skipping...  City (solovetskiy, ru) is not found.
# Processing Record 544 (44 of set 11) | Daru, PG
# Processing Record 545 (45 of set 11) | Olkhovka, RU
# Processing Record 546 (46 of set 11) | Sinnamary, GF
# Processing Record 547 (47 of set 11) | Sturgeon Bay, US
# Processing Record 548 (48 of set 11) | Zhumadian, CN
# Processing Record 549 (49 of set 11) | Olafsvik, IS
# Processing Record 550 (50 of set 11) | Jammalamadugu, IN
# Processing Record 551 (1 of set 12) | Kajansi, UG
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
# weather_data
# Print the json (pretty printed)
# print(json.dumps(weather_data, indent=4, sort_keys=True))

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({
    "City" : city_data,
    "Country" : country_data,
    "Cloudiness" : cloudCover_data,
    "Date" : date_data,
    "Humidity" : humidity_data,
    "Lat" : lat_data,
    "Lng" : lng_data,
    "Temp" : temp_data,
    "Max Temp" : maxTemp_data,
    "Wind Speed" : windSpeed_data
})

# %%
# count the number of records in each column to make sure they all match
weather_df.count()
# Out:
# City          551
# Country       551
# Cloudiness    551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Temp          551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %%
# show the top 5 rows of the data frame
weather_df.head()
# Out:
#            City Country  Cloudiness        Date  Humidity    Lat     Lng  \
# 0        Barrow      US           1  1579917160        68  71.29 -156.79
# 1      Victoria      SC          20  1579917460        83  -4.62   55.45
# 2       Ternate      ID          41  1579917460        58   0.80  127.40
# 3  Puerto Ayora      EC          23  1579917460        57  -0.74  -90.35
# 4        Avarua      CK          80  1579917174        88 -21.21 -159.78
#
#     Temp  Max Temp  Wind Speed
# 0 -18.40    -18.40       10.29
# 1  82.40     82.40        3.36
# 2  87.67     87.67        5.39
# 3  77.00     77.00        1.01
# 4  82.40     82.40        8.05

# %%
# export/save dataframe to csv file (to avoid potential issues later, using encoding="utf-8")
# weather_df.to_csv(output_data_file, encoding="utf-8", index=False)
weather_df.to_csv(f"{output_data_filepath}cities_weather.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Generate a scatter plot of Latitude vs. Temperature (max)

# create two lists of the data to be plotted on the scatter plot
# latVStemp_x_values = weather_df["Lat"].tolist()
latVStemp_x_values = weather_df.iloc[:,5]
# latVStemp_y_values = weather_df["Max Temp"].tolist()
latVStemp_y_values = weather_df.iloc[:,8]

# date_for_plot = datetime.datetime.fromtimestamp(min(weather_df["Date"])).strftime('%m/%d/%Y')
date_for_plot = datetime.datetime.fromtimestamp(sum(weather_df["Date"]) / len(weather_df["Date"])).strftime("%m/%d/%Y")

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(latVStemp_x_values,
            latVStemp_y_values,
#             color="blue",
            edgecolors='black'
           )
# plt.title(f"City Latitude vs. Max Temperature (xxDATExx)")
plt.title(f"City Latitude vs. Max Temperature ({date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# export/save figure to png file
plt.savefig(f"{output_data_filepath}latitude_vs_temp_plot.png")

plt.show()

# %% [markdown]
# ### City Latitude vs. Temperature (max): what the code is and what is it analyzing?
#
# *  What the code is doing...
#     *  First, extracting x and y values for the scatter plot from the weather data frame.  X is the Latitude; Y is the Max Temperature for the cities randomly selected from across the globe.
#     *  Then, the date value is averaged (between all values; all same date, minor variance in unix timestamp, presumably because of when that city's lats/longs were called using the API).  Averaging to get one usable value, then converting from unix to a readable date format and inserting into title of the scatter plot.
#     *  Finally, we set the size of the plot, plot the values, set some chart properties, create labels, create an image file and show the plot in the jupyter notebook.
#
# *  What is the chart analyzing...
#     *  We are looking at the max temperatures for cities in our data frame in relation to its Latitude (north/south position).  Currently, in January we are in the middle of winter in the northern hemisphere and we see a pattern.  Temperatures appear to be aggressively lower on the right side of the chart - lower as we get closer to the north pole where the earth is tilted most away from the sun.  Conversely, on the left side of the chart - toward the south pole - the temperatures are all much higher as the south end of the earth is positioned closer to the sun during the Southern Hemisphere's summer.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Generate a scatter plot of Latitude vs. Humidity

# create two lists of the data to be plotted on the scatter plot
latVShumidity_x_values = weather_df.iloc[:,5]
latVShumidity_y_values = weather_df.iloc[:,4]

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(latVShumidity_x_values,
            latVShumidity_y_values,
#             color="blue",
            edgecolors='black'
           )
plt.title(f"City Latitude vs. Humidity ({date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# export/save figure to png file
plt.savefig(f"{output_data_filepath}latitude_vs_humidity_plot.png")

plt.show()

# %% [markdown]
# ### City Latitude vs. Humidity: what the code is and what is it analyzing?
#
# *  What the code is doing...
#     *  First, extract x and y values for the scatter plot from the weather data frame.  X is the Latitude; Y is the Percent Humidity.
#     *  Then, the size of the plot is set, values plotted, chart properties set, labels created, an image file is created and then the plot is shown.
#
# *  What is the chart analyzing...
#     *  We are looking at the humidity % for cities in our data frame in relation to its Latitude.  There doesn’t appear to be a very strong correlation between latitude and humidity for our cities.  While it looks like there are a higher number data points of high humidity (~>70%) vs lower, more might slightly appear on the right side (or at higher latitudes), there are quite a few also on the left side (southern hemisphere), concentrated heavily -20 to 0 Latitudes.  Latitude doesn't appear to affect humidity.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Generate a scatter plot of Latitude vs. Cloudiness

# create two lists of the data to be plotted on the scatter plot
latVScloudiness_x_values = weather_df.iloc[:,5]
latVScloudiness_y_values = weather_df.iloc[:,2]

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(latVScloudiness_x_values,
            latVScloudiness_y_values,
#             color="blue",
            edgecolors='black'
           )
plt.title(f"City Latitude vs. Cloudiness ({date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# export/save figure to png file
plt.savefig(f"{output_data_filepath}latitude_vs_cloudiness_plot.png")

plt.show()

# %% [markdown]
# ### City Latitude vs. Cloudiness: what the code is and what is it analyzing?
#
# *  What the code is doing...
#     *  Same as above, but the Y value plotted is the Percent Cloudiness.
#
# *  What is the chart analyzing...
#     *  In this scatter plot, the % cloud cover is plotted for cities in our data frame in relation to its Latitude.  There does not appear to much of a correlation at all between latitude and cloudiness.  From eyeballing it, it is interesting to me to note the common percentages reported: 0%, 20%, 40%, 75%, 90% and 100%.  You can almost connect the dots to get a horizontal line with those data points.  It appears that the percent cloudiness measurement may be more subjective - or what a human observer is reporting vs an actual measurement by weather instruments.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Generate a scatter plot of Latitude vs. Wind Speed

# create two lists of the data to be plotted on the scatter plot
latVSwindspeed_x_values = weather_df.iloc[:,5]
latVSwindspeed_y_values = weather_df.iloc[:,9]

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(latVSwindspeed_x_values,
            latVSwindspeed_y_values,
#             color="blue",
            edgecolors='black'
           )
plt.title(f"City Latitude vs. Wind Speed ({date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# export/save figure to png file
plt.savefig(f"{output_data_filepath}latitude_vs_wind_speed_plot.png")

plt.show()

# %% [markdown]
# ### City Latitude vs. Wind Speed: what the code is and what is it analyzing?
#
# *  What the code is doing...
#     *  Same as above, but the Y value plotted is the wind speed, in miles per hour.
#
# *  What is the chart analyzing...
#     *  In this scatter plot, the wind speeds are plotted for cities in our data frame in relation to its N/S position.  Again, there does not appear to much of a correlation at all between latitude and wind speed.  Most of the points appear between 0 and 10 mph from north to south pole, with various other higher wind speed points scattered throughout.  Though higher wind speeds appear to possibly be polarized.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# #### OPTIONAL: Create a function to create Linear Regression plots

# %%
# create function to calculate the linear regression plots and various other linregress() values
def lr_func(x_value, y_value):
    (slope_value, intercept_value, r_value, p_value, stderr_value) = linregress(x_value, y_value)
    line_eq_value = "y = " + str(round(slope_value,2)) + "x + " + str(round(intercept_value,2))
    regress_values = x_value * slope_value + intercept_value
#     return slope_value, intercept_value, r_value, p_value, stderr_value, line_eq_value, [regress_values]
    return {"slope_value": slope_value,
            "intercept_value": intercept_value,
            "r_value": r_value,
            "p_value": p_value,
            "stderr_value": stderr_value,
            "line_eq_value": line_eq_value,
            "regress_values": regress_values
    }

# %%
# create Northern and Southern Hemisphere data frames
n_hmsphr_wx_df = weather_df.loc[weather_df["Lat"] >= 0 ,:]
s_hmsphr_wx_df = weather_df.loc[weather_df["Lat"] < 0 ,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
n_latVStemp_x_values = n_hmsphr_wx_df.iloc[:,5]
n_latVStemp_y_values = n_hmsphr_wx_df.iloc[:,8]
n_latVStemp_r_value = lr_func(n_latVStemp_x_values, n_latVStemp_y_values)["r_value"]
n_latVStemp_on_plot_label_x_loc = min(n_latVStemp_x_values)
n_latVStemp_on_plot_label_y_loc = min(n_latVStemp_y_values)

# date_for_plot = datetime.datetime.fromtimestamp(min(weather_df["Date"])).strftime('%m/%d/%Y')
n_date_for_plot = datetime.datetime.fromtimestamp(sum(n_hmsphr_wx_df["Date"]) / len(n_hmsphr_wx_df["Date"])).strftime("%m/%d/%Y")

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(n_latVStemp_x_values,
            n_latVStemp_y_values,
            edgecolors='black'
           )
plt.title(f"Northern Hemisphere City Latitude vs. Max Temperature ({n_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# # Plot regression line
plt.plot(n_latVStemp_x_values,lr_func(n_latVStemp_x_values, n_latVStemp_y_values)["regress_values"],"r-")
plt.annotate(lr_func(n_latVStemp_x_values, n_latVStemp_y_values)["line_eq_value"],
#              (6,10),
             (n_latVStemp_on_plot_label_x_loc ,n_latVStemp_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red")

# # Print r square value
print(f"The r-squared value is: {n_latVStemp_r_value}")
plt.annotate(f"R^2 = {n_latVStemp_r_value.round(3)}",
#              (6,0),
             (n_latVStemp_on_plot_label_x_loc ,n_latVStemp_on_plot_label_y_loc),
             fontsize=12,
             color="red")

# export/save figure to png file
plt.savefig(f"{output_data_filepath}n_hemis_latitude_vs_temp_plot.png")

plt.show()
# Out:
# The r-squared value is: -0.841813053173974

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
s_latVStemp_x_values = s_hmsphr_wx_df.iloc[:,5]
s_latVStemp_y_values = s_hmsphr_wx_df.iloc[:,8]
s_latVStemp_r_value = lr_func(s_latVStemp_x_values, s_latVStemp_y_values)["r_value"]
s_latVStemp_on_plot_label_x_loc = min(s_latVStemp_x_values)
s_latVStemp_on_plot_label_y_loc = min(s_latVStemp_y_values)

# date_for_plot = datetime.datetime.fromtimestamp(min(weather_df["Date"])).strftime('%m/%d/%Y')
s_date_for_plot = datetime.datetime.fromtimestamp(sum(s_hmsphr_wx_df["Date"]) / len(s_hmsphr_wx_df["Date"])).strftime("%m/%d/%Y")

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(s_latVStemp_x_values,
            s_latVStemp_y_values,
            edgecolors='black'
           )
plt.title(f"Southern Hemisphere City Latitude vs. Max Temperature ({s_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# # Plot regression line
plt.plot(s_latVStemp_x_values,lr_func(s_latVStemp_x_values, s_latVStemp_y_values)["regress_values"],"r-")
plt.annotate(lr_func(s_latVStemp_x_values, s_latVStemp_y_values)["line_eq_value"],
             (s_latVStemp_on_plot_label_x_loc ,s_latVStemp_on_plot_label_y_loc + 3.5),
             fontsize=12,
             color="red")

# # Print r square value
print(f"The r-squared value is: {s_latVStemp_r_value}")
plt.annotate(f"R^2 = {s_latVStemp_r_value.round(3)}",
             (s_latVStemp_on_plot_label_x_loc ,s_latVStemp_on_plot_label_y_loc),
             fontsize=12,
             color="red")

# export/save figure to png file
plt.savefig(f"{output_data_filepath}s_hemis_latitude_vs_temp_plot.png")

plt.show()
# Out:
# The r-squared value is: 0.3718788032217586

# %% [markdown]
# ### Northern/Southern Hemisphere City Latitude vs. Temperature (max):
#
# *  What the linear regression is modeling & other analysis/commentary...
#     *  As mentioned in the Latitude vs Max Temperature where both Northern and Southern hemispheres cities are plotted, there does appear to be a correlation between the two - and the linear regression model appears to support this.  Correlation appears much stronger in the northern hemisphere with an R-squared value of 0.84, less so in the southern hemisphere, but still the points generally trend lower on the left side (lower latitudes; extremely cold temps toward the pole) and the higher on the right side closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
n_latVShumidity_x_values = n_hmsphr_wx_df.iloc[:,5]
n_latVShumidity_y_values = n_hmsphr_wx_df.iloc[:,4]
n_latVShumidity_r_value = lr_func(n_latVShumidity_x_values, n_latVShumidity_y_values)["r_value"]
n_latVShumidity_on_plot_label_x_loc = min(n_latVShumidity_x_values)
n_latVShumidity_on_plot_label_y_loc = min(n_latVShumidity_y_values)

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(n_latVShumidity_x_values,
            n_latVShumidity_y_values,
            edgecolors='black'
           )
plt.title(f"Northern Hemisphere City Latitude vs. Humidity ({n_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Plot regression line
plt.plot(n_latVShumidity_x_values,lr_func(n_latVShumidity_x_values, n_latVShumidity_y_values)["regress_values"],"r-")
plt.annotate(lr_func(n_latVShumidity_x_values, n_latVShumidity_y_values)["line_eq_value"],
             (n_latVShumidity_on_plot_label_x_loc ,n_latVShumidity_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red"
             )

# Print r square value
print(f"The r-squared value is: {n_latVShumidity_r_value}")
plt.annotate(f"R^2 = {n_latVShumidity_r_value.round(3)}",
             (n_latVShumidity_on_plot_label_x_loc ,n_latVShumidity_on_plot_label_y_loc),
             fontsize=12,
             color="red"
             )

# export/save figure to png file
plt.savefig(f"{output_data_filepath}n_hemis_latitude_vs_humidity_plot.png")

plt.show()
# Out:
# The r-squared value is: 0.38392962153544885

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
s_latVShumidity_x_values = s_hmsphr_wx_df.iloc[:,5]
s_latVShumidity_y_values = s_hmsphr_wx_df.iloc[:,4]
s_latVShumidity_r_value = lr_func(s_latVShumidity_x_values, s_latVShumidity_y_values)["r_value"]
s_latVShumidity_on_plot_label_x_loc = min(s_latVShumidity_x_values)
s_latVShumidity_on_plot_label_y_loc = min(s_latVShumidity_y_values)

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(s_latVShumidity_x_values,
            s_latVShumidity_y_values,
            edgecolors='black'
           )
plt.title(f"Southern Hemisphere City Latitude vs. Humidity ({s_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Plot regression line
plt.plot(s_latVShumidity_x_values,lr_func(s_latVShumidity_x_values, s_latVShumidity_y_values)["regress_values"],"r-")
plt.annotate(lr_func(s_latVShumidity_x_values, s_latVShumidity_y_values)["line_eq_value"],
             (s_latVShumidity_on_plot_label_x_loc ,s_latVShumidity_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red"
             )

# Print r square value
print(f"The r-squared value is: {s_latVShumidity_r_value}")
plt.annotate(f"R^2 = {s_latVShumidity_r_value.round(3)}",
             (s_latVShumidity_on_plot_label_x_loc ,s_latVShumidity_on_plot_label_y_loc),
             fontsize=12,
             color="red"
             )

# export/save figure to png file
plt.savefig(f"{output_data_filepath}s_hemis_latitude_vs_humidity_plot.png")

plt.show()
# Out:
# The r-squared value is: 0.2607303237630865

# %% [markdown]
# ### Northern/Southern Hemisphere City Latitude vs. Humidity:
#
# *  What the linear regression is modeling & other analysis/commentary...
#     *  These linear regression plots are plotting the cities latitudes and levels of humidity, for the northern and southern hemispheres, respectively.  There does not appear to be too strong of a correlation in the two data points in the northern hemisphere, far weaker in the southern hemisphere where the points are spread further from the linear regression plot.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
n_latVScloudiness_x_values = n_hmsphr_wx_df.iloc[:,5]
n_latVScloudiness_y_values = n_hmsphr_wx_df.iloc[:,2]
n_latVScloudiness_r_value = lr_func(n_latVScloudiness_x_values, n_latVScloudiness_y_values)["r_value"]
n_latVScloudiness_on_plot_label_x_loc = min(n_latVScloudiness_x_values)
n_latVScloudiness_on_plot_label_y_loc = min(n_latVScloudiness_y_values)

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(n_latVScloudiness_x_values,
            n_latVScloudiness_y_values,
            edgecolors='black'
           )
plt.title(f"Northern Hemisphere City Latitude vs. Cloudiness ({n_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Plot regression line
plt.plot(n_latVScloudiness_x_values,lr_func(n_latVScloudiness_x_values, n_latVScloudiness_y_values)["regress_values"],"r-")
plt.annotate(lr_func(n_latVScloudiness_x_values, n_latVScloudiness_y_values)["line_eq_value"],
             (n_latVScloudiness_on_plot_label_x_loc ,n_latVScloudiness_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red"
             )

# Print r square value
print(f"The r-squared value is: {n_latVScloudiness_r_value}")
plt.annotate(f"R^2 = {n_latVScloudiness_r_value.round(3)}",
             (n_latVScloudiness_on_plot_label_x_loc ,n_latVScloudiness_on_plot_label_y_loc),
             fontsize=12,
             color="red"
             )

# export/save figure to png file
plt.savefig(f"{output_data_filepath}n_hemis_latitude_vs_cloudiness_plot.png")

plt.show()
# Out:
# The r-squared value is: 0.2373445905333556

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
s_latVScloudiness_x_values = s_hmsphr_wx_df.iloc[:,5]
s_latVScloudiness_y_values = s_hmsphr_wx_df.iloc[:,2]
s_latVScloudiness_r_value = lr_func(s_latVScloudiness_x_values, s_latVScloudiness_y_values)["r_value"]
s_latVScloudiness_on_plot_label_x_loc = min(s_latVScloudiness_x_values)
s_latVScloudiness_on_plot_label_y_loc = min(s_latVScloudiness_y_values)

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(s_latVScloudiness_x_values,
            s_latVScloudiness_y_values,
            edgecolors='black'
           )
plt.title(f"Southern Hemisphere City Latitude vs. Cloudiness ({s_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Plot regression line
plt.plot(s_latVScloudiness_x_values,lr_func(s_latVScloudiness_x_values, s_latVScloudiness_y_values)["regress_values"],"r-")
plt.annotate(lr_func(s_latVScloudiness_x_values, s_latVScloudiness_y_values)["line_eq_value"],
             (s_latVScloudiness_on_plot_label_x_loc ,s_latVScloudiness_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red"
             )

# Print r square value
print(f"The r-squared value is: {s_latVScloudiness_r_value}")
plt.annotate(f"R^2 = {s_latVScloudiness_r_value.round(3)}",
             (s_latVScloudiness_on_plot_label_x_loc ,s_latVScloudiness_on_plot_label_y_loc),
             fontsize=12,
             color="red"
             )

# export/save figure to png file
plt.savefig(f"{output_data_filepath}s_hemis_latitude_vs_cloudiness_plot.png")

plt.show()
# Out:
# The r-squared value is: 0.28275105297172265

# %% [markdown]
# ### Northern/Southern Hemisphere City Latitude vs. Cloudiness:
#
# *  What the linear regression is modeling & other analysis/commentary...
#     *  These linear regression plots are plotting the cities latitudes and percentage of cloud cover, for the northern and southern hemispheres, respectively.  Once again, there appears to be a weak correlation with points scattered broadly and well away from the linear regression plot line.  And similar to where the northern and southern hemisphere cities were plotted together, common measurements value appear.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
n_latVSwindspeed_x_values = n_hmsphr_wx_df.iloc[:,5]
n_latVSwindspeed_y_values = n_hmsphr_wx_df.iloc[:,9]
n_latVSwindspeed_r_value = lr_func(n_latVSwindspeed_x_values, n_latVSwindspeed_y_values)["r_value"]
n_latVSwindspeed_on_plot_label_x_loc = min(n_latVSwindspeed_x_values)
n_latVSwindspeed_on_plot_label_y_loc = min(n_latVSwindspeed_y_values)

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(n_latVSwindspeed_x_values,
            n_latVSwindspeed_y_values,
            edgecolors='black'
           )
plt.title(f"Northern Hemisphere City Latitude vs. Wind Speed ({n_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Plot regression line
plt.plot(n_latVSwindspeed_x_values,lr_func(n_latVSwindspeed_x_values, n_latVSwindspeed_y_values)["regress_values"],"r-")
plt.annotate(lr_func(n_latVSwindspeed_x_values, n_latVSwindspeed_y_values)["line_eq_value"],
             (n_latVSwindspeed_on_plot_label_x_loc ,n_latVSwindspeed_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red"
             )

# Print r square value
print(f"The r-squared value is: {n_latVSwindspeed_r_value}")
plt.annotate(f"R^2 = {n_latVSwindspeed_r_value.round(3)}",
             (n_latVSwindspeed_on_plot_label_x_loc ,n_latVSwindspeed_on_plot_label_y_loc),
             fontsize=12,
             color="red"
             )

# export/save figure to png file
plt.savefig(f"{output_data_filepath}n_hemis_latitude_vs_windspeed_plot.png")

plt.show()
# Out:
# The r-squared value is: 0.13584417788791636

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
s_latVSwindspeed_x_values = s_hmsphr_wx_df.iloc[:,5]
s_latVSwindspeed_y_values = s_hmsphr_wx_df.iloc[:,9]
s_latVSwindspeed_r_value = lr_func(s_latVSwindspeed_x_values, s_latVSwindspeed_y_values)["r_value"]
s_latVSwindspeed_on_plot_label_x_loc = min(s_latVSwindspeed_x_values)
s_latVSwindspeed_on_plot_label_y_loc = min(s_latVSwindspeed_y_values)

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(s_latVSwindspeed_x_values,
            s_latVSwindspeed_y_values,
            edgecolors='black'
           )
plt.title(f"Southern Hemisphere City Latitude vs. Wind Speed ({s_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Plot regression line
plt.plot(s_latVSwindspeed_x_values,lr_func(s_latVSwindspeed_x_values, s_latVSwindspeed_y_values)["regress_values"],"r-")
plt.annotate(lr_func(s_latVSwindspeed_x_values, s_latVSwindspeed_y_values)["line_eq_value"],
             (s_latVSwindspeed_on_plot_label_x_loc ,s_latVSwindspeed_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red"
             )

# Print r square value
print(f"The r-squared value is: {s_latVSwindspeed_r_value}")
plt.annotate(f"R^2 = {s_latVSwindspeed_r_value.round(3)}",
             (s_latVSwindspeed_on_plot_label_x_loc ,s_latVSwindspeed_on_plot_label_y_loc),
             fontsize=12,
             color="red"
             )

# export/save figure to png file
plt.savefig(f"{output_data_filepath}s_hemis_latitude_vs_windspeed_plot.png")

plt.show()
# Out:
# The r-squared value is: -0.26195829800448545

# %% [markdown]
# ### Northern/Southern Hemisphere City Latitude vs. Wind Speed:
#
# *  What the linear regression is modeling & other analysis/commentary...
#     *  These linear regression plots are plotting the cities latitudes and wind speed, for the northern and southern hemispheres, respectively.  There is an incredibly weak correlation in the northern hemisphere, slightly better in the south, albeit still considered weak.
