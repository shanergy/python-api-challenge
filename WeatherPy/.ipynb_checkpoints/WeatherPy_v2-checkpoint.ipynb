# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## Dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
import time
import datetime
from scipy.stats import linregress

# import API keys:
from config import weather_api_key, g_key

# bring in and use citipy to determine city based on latitude and longitude
from citipy import citipy

# set the output csv file & png image output data filepath
# output_data_file = "output_data/cities.csv"
output_data_filepath = "output_data/"

# set the range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate a Cities List

# %%
# create list for holding cities, countries, latitudes, longitudes and weather data
cities = []
countries = []
cities_countries = []
lat_lngs = []

# create set of random latitude/longitude combinations        #### NOTE: UPDATE SIZE BACK TO 1500 ####
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# identify the nearest city for each latitude/longitude combo
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # if the city is unique, then add it to the list: cities
    if city not in cities:
        cities.append(city)
        countries.append(country)
        cities_countries.append([city,country])
        
# print the city count in the list cities to confirm we have a sufficient count
# len(cities)
print(f"The number of random cities in the list is {len(cities_countries)}")
# Out:
# The number of random cities in the list is 593

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# setup lists to hold data retrieved and inserted from API call
weather_data = []
city_data = []
cloudCover_data = []
country_data = []
date_data = []
humidity_data = []
lat_data = []
lng_data = []
temp_data = []
maxTemp_data = []
windSpeed_data = []

# setup counters, initially set to 1, to count cities with API calls that successfully retrieve data
city_counter = 1
set_of_cities_counter = 1
city_in_set_counter = 1

# setup pieces of API call url/address (base_url and units)
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# perform the API call...fingers crossed, here we go!

# start log for data retrieval from API Call
print("Beginning Data Retrieval")
print("-----------------------------")

# loop through cities & complete API call for each; append weather_data with data when successful
for x in range(len(cities_countries)):
    q_city = cities[x]
    q_city = cities_countries[x][0]
#     q_country = countries[x]
    q_country = cities_countries[x][1]
#     query_url = f"{base_url}appid={weather_api_key}&units={units}&q={cities_countries[x][0]},{cities_countries[x][1]}"
#     query_url = f"{base_url}appid={weather_api_key}&units={units}&q={q_city}"
    query_url = f"{base_url}appid={weather_api_key}&units={units}&q={q_city},{q_country}"
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()

# exception handling for when there is no data returned from the API call
    try:
#         print(f"Processing Record {x} of Set xxXXXxx | {q_city}, {q_country}")
#         print(f"Processing Record {x} | {q_city}, {q_country}")
#         print(f"Processing Record {x} of Set xxXXXxx | {q_city}")
#         print(f"Processing Record {x} | {q_city}")
#         print(f"Processing Record {x} | {weather_json['name']}")
#         print(f"Processing Record {city_counter} | {weather_json['name']}, {weather_json['sys']['country']}")
        print(f"Processing Record {city_counter} ({city_in_set_counter} of set {set_of_cities_counter}) | {weather_json['name']}, {weather_json['sys']['country']}")
        weather_data.append(weather_json)

        # append lists with new data (to be placed in data frame later)
        city_data.append(weather_json["name"])
        country_data.append(weather_json["sys"]["country"])
        cloudCover_data.append(weather_json["clouds"]["all"])
        date_data.append(weather_json["dt"])
        humidity_data.append(weather_json["main"]["humidity"])
        lat_data.append(weather_json["coord"]["lat"])
        lng_data.append(weather_json["coord"]["lon"])
        temp_data.append(weather_json["main"]["temp"])
        maxTemp_data.append(weather_json["main"]["temp_max"])
        windSpeed_data.append(weather_json["wind"]["speed"])

        # update counters
        city_counter += 1
        
        # for set counters, once 50 is reached: reset city_in_set_counter = 1 and add 1 to set_of_cities_counter
        if city_in_set_counter >= 50:
            set_of_cities_counter += 1
            city_in_set_counter = 1
        else:
            city_in_set_counter += 1

    except:
#         print(f"Skipping...  City ({q_city}) is not found.")
        print(f"Skipping...  City ({q_city}, {q_country}) is not found.")
              
# end log for data retrieval; print "Data Retrieval Complete" when at the end of the loop
    if x == max(range(len(cities_countries))):
        print("----------------------------")
        print("Data Retrieval Complete")
        print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 (1 of set 1) |             Brookhaven, US
# Processing Record 2 (2 of set 1) |             Upernavik, GL
# Processing Record 3 (3 of set 1) |             Kimbe, PG
# Processing Record 4 (4 of set 1) |             Bobrovytsya, UA
# Processing Record 5 (5 of set 1) |             Ust-Nera, RU
# Skipping...  City (taolanaro, mg) is not found.
# Skipping...  City (mataura, pf) is not found.
# Skipping...  City (miranorte, br) is not found.
# Processing Record 6 (6 of set 1) |             Pisco, PE
# Processing Record 7 (7 of set 1) |             Ilulissat, GL
# Processing Record 8 (8 of set 1) |             Puerto Ayora, EC
# Processing Record 9 (9 of set 1) |             Waipawa, NZ
# Skipping...  City (karamay, cn) is not found.
# Processing Record 10 (10 of set 1) |             Ushuaia, AR
# Processing Record 11 (11 of set 1) |             Punta Arenas, CL
# Processing Record 12 (12 of set 1) |             Pangody, RU
# Processing Record 13 (13 of set 1) |             Svolvaer, NO
# Processing Record 14 (14 of set 1) |             Tarifa, ES
# Processing Record 15 (15 of set 1) |             Kaitangata, NZ
# Processing Record 16 (16 of set 1) |             Bluff, NZ
# Processing Record 17 (17 of set 1) |             Khatanga, RU
# Processing Record 18 (18 of set 1) |             Luderitz, NA
# Skipping...  City (belushya guba, ru) is not found.
# Processing Record 19 (19 of set 1) |             Vaini, TO
# Processing Record 20 (20 of set 1) |             Hermanus, ZA
# Processing Record 21 (21 of set 1) |             Mahebourg, MU
# Processing Record 22 (22 of set 1) |             Aksarka, RU
# Skipping...  City (barentsburg, sj) is not found.
# Processing Record 23 (23 of set 1) |             Katsuura, JP
# Processing Record 24 (24 of set 1) |             Busselton, AU
# Processing Record 25 (25 of set 1) |             Maryborough, AU
# Processing Record 26 (26 of set 1) |             East London, ZA
# Skipping...  City (mys shmidta, ru) is not found.
# Processing Record 27 (27 of set 1) |             Maniitsoq, GL
# Processing Record 28 (28 of set 1) |             Nouadhibou, MR
# Skipping...  City (airai, pw) is not found.
# Processing Record 29 (29 of set 1) |             Amahai, ID
# Processing Record 30 (30 of set 1) |             Albany, AU
# Processing Record 31 (31 of set 1) |             Hobart, AU
# Skipping...  City (avera, pf) is not found.
# Processing Record 32 (32 of set 1) |             Rikitea, PF
# Skipping...  City (nioro, ml) is not found.
# Processing Record 33 (33 of set 1) |             Seoul, KR
# Processing Record 34 (34 of set 1) |             Klaksvik, FO
# Processing Record 35 (35 of set 1) |             Alcaniz, ES
# Processing Record 36 (36 of set 1) |             Dumas, US
# Skipping...  City (faya, td) is not found.
# Processing Record 37 (37 of set 1) |             Cape Town, ZA
# Processing Record 38 (38 of set 1) |             Lebu, CL
# Processing Record 39 (39 of set 1) |             Kamenka, RU
# Processing Record 40 (40 of set 1) |             Ginir, ET
# Processing Record 41 (41 of set 1) |             Arraial do Cabo, BR
# Processing Record 42 (42 of set 1) |             Yellowknife, CA
# Processing Record 43 (43 of set 1) |             Hilo, US
# Processing Record 44 (44 of set 1) |             Pouembout, NC
# Processing Record 45 (45 of set 1) |             Tura, RU
# Processing Record 46 (46 of set 1) |             Takoradze, GH
# Processing Record 47 (47 of set 1) |             Tasiilaq, GL
# Processing Record 48 (48 of set 1) |             Iqaluit, CA
# Processing Record 49 (49 of set 1) |             Kulhudhuffushi, MV
# Processing Record 50 (50 of set 1) |             Bethel, US
# Processing Record 51 (1 of set 2) |             Kapaa, US
# Skipping...  City (amderma, ru) is not found.
# Processing Record 52 (2 of set 2) |             Marilia, BR
# Processing Record 53 (3 of set 2) |             Victoria, SC
# Processing Record 54 (4 of set 2) |             Ustynivka, UA
# Processing Record 55 (5 of set 2) |             Virginia Beach, US
# Processing Record 56 (6 of set 2) |             Havre-Saint-Pierre, CA
# Skipping...  City (tumannyy, ru) is not found.
# Processing Record 57 (7 of set 2) |             Barrow, US
# Processing Record 58 (8 of set 2) |             Nyurba, RU
# Processing Record 59 (9 of set 2) |             New Glasgow, CA
# Processing Record 60 (10 of set 2) |             Pahrump, US
# Processing Record 61 (11 of set 2) |             Tautira, PF
# Processing Record 62 (12 of set 2) |             Jamestown, SH
# Processing Record 63 (13 of set 2) |             Bonthe, SL
# Processing Record 64 (14 of set 2) |             Mar del Plata, AR
# Processing Record 65 (15 of set 2) |             Hithadhoo, MV
# Processing Record 66 (16 of set 2) |             Coyhaique, CL
# Processing Record 67 (17 of set 2) |             Jackson, US
# Processing Record 68 (18 of set 2) |             Noumea, NC
# Skipping...  City (tsihombe, mg) is not found.
# Processing Record 69 (19 of set 2) |             Carnarvon, AU
# Skipping...  City (arkhangelos, gr) is not found.
# Processing Record 70 (20 of set 2) |             Maceio, BR
# Processing Record 71 (21 of set 2) |             Yar-Sale, RU
# Processing Record 72 (22 of set 2) |             Linxia, CN
# Processing Record 73 (23 of set 2) |             Hasaki, JP
# Skipping...  City (west bridgeford, gb) is not found.
# Processing Record 74 (24 of set 2) |             Maicao, CO
# Processing Record 75 (25 of set 2) |             Ryazan, RU
# Processing Record 76 (26 of set 2) |             Tezu, IN
# Processing Record 77 (27 of set 2) |             Barabai, ID
# Processing Record 78 (28 of set 2) |             Cherskiy, RU
# Processing Record 79 (29 of set 2) |             Mareeba, AU
# Processing Record 80 (30 of set 2) |             Chokurdakh, RU
# Processing Record 81 (31 of set 2) |             Port Alfred, ZA
# Processing Record 82 (32 of set 2) |             Medvedka, RU
# Processing Record 83 (33 of set 2) |             Cerkezkoey, TR
# Processing Record 84 (34 of set 2) |             Potam, MX
# Processing Record 85 (35 of set 2) |             Vila Franca do Campo, PT
# Processing Record 86 (36 of set 2) |             Narsaq, GL
# Processing Record 87 (37 of set 2) |             Faanui, PF
# Processing Record 88 (38 of set 2) |             Dikson, RU
# Processing Record 89 (39 of set 2) |             Avarua, CK
# Processing Record 90 (40 of set 2) |             New Norfolk, AU
# Processing Record 91 (41 of set 2) |             Saint-Philippe, RE
# Processing Record 92 (42 of set 2) |             Bud, NO
# Processing Record 93 (43 of set 2) |             Bredasdorp, ZA
# Processing Record 94 (44 of set 2) |             Nishihara, JP
# Processing Record 95 (45 of set 2) |             Galesong, ID
# Processing Record 96 (46 of set 2) |             Qaanaaq, GL
# Processing Record 97 (47 of set 2) |             Kampene, CD
# Processing Record 98 (48 of set 2) |             Ossora, RU
# Processing Record 99 (49 of set 2) |             Yenagoa, NG
# Skipping...  City (bur gabo, so) is not found.
# Processing Record 100 (50 of set 2) |             Rock Springs, US
# Processing Record 101 (1 of set 3) |             Baton Rouge, US
# Processing Record 102 (2 of set 3) |             Riyadh, SA
# Processing Record 103 (3 of set 3) |             Sitka, US
# Processing Record 104 (4 of set 3) |             Leningradskiy, RU
# Processing Record 105 (5 of set 3) |             Atuona, PF
# Processing Record 106 (6 of set 3) |             Saldanha, ZA
# Processing Record 107 (7 of set 3) |             Marsh Harbour, BS
# Processing Record 108 (8 of set 3) |             Safford, US
# Processing Record 109 (9 of set 3) |             Nikolskoye, RU
# Processing Record 110 (10 of set 3) |             Baykit, RU
# Processing Record 111 (11 of set 3) |             Deer Lake, CA
# Processing Record 112 (12 of set 3) |             Butaritari, KI
# Skipping...  City (shaartuz, tj) is not found.
# Processing Record 113 (13 of set 3) |             Vardo, NO
# Processing Record 114 (14 of set 3) |             Pevek, RU
# Processing Record 115 (15 of set 3) |             Port Shepstone, ZA
# Skipping...  City (nizhneyansk, ru) is not found.
# Processing Record 116 (16 of set 3) |             Alice Springs, AU
# Processing Record 117 (17 of set 3) |             Anadyr, RU
# Processing Record 118 (18 of set 3) |             Provideniya, RU
# Processing Record 119 (19 of set 3) |             Aklavik, CA
# Processing Record 120 (20 of set 3) |             Bubaque, GW
# Skipping...  City (sahrak, af) is not found.
# Processing Record 121 (21 of set 3) |             Agadez, NE
# Processing Record 122 (22 of set 3) |             Yulara, AU
# Processing Record 123 (23 of set 3) |             Kiama, AU
# Processing Record 124 (24 of set 3) |             Falun, SE
# Processing Record 125 (25 of set 3) |             Monrovia, LR
# Skipping...  City (sentyabrskiy, ru) is not found.
# Skipping...  City (illoqqortoormiut, gl) is not found.
# Processing Record 126 (26 of set 3) |             Merowe, SD
# Processing Record 127 (27 of set 3) |             River Falls, US
# Skipping...  City (tapaua, br) is not found.
# Processing Record 128 (28 of set 3) |             Kruisfontein, ZA
# Processing Record 129 (29 of set 3) |             Port Lincoln, AU
# Processing Record 130 (30 of set 3) |             Portland, AU
# Processing Record 131 (31 of set 3) |             Trelaze, FR
# Processing Record 132 (32 of set 3) |             Redmond, US
# Processing Record 133 (33 of set 3) |             San Patricio, MX
# Skipping...  City (vaitupu, wf) is not found.
# Processing Record 134 (34 of set 3) |             Tuatapere, NZ
# Processing Record 135 (35 of set 3) |             Bolobo, CD
# Skipping...  City (khani, ru) is not found.
# Processing Record 136 (36 of set 3) |             Northam, AU
# Skipping...  City (pousat, kh) is not found.
# Processing Record 137 (37 of set 3) |             Shubarshi, KZ
# Processing Record 138 (38 of set 3) |             Clyde River, CA
# Skipping...  City (karakendzha, tj) is not found.
# Processing Record 139 (39 of set 3) |             Sarakhs, IR
# Processing Record 140 (40 of set 3) |             Urumqi, CN
# Processing Record 141 (41 of set 3) |             Caetite, BR
# Processing Record 142 (42 of set 3) |             Meulaboh, ID
# Processing Record 143 (43 of set 3) |             Itoman, JP
# Processing Record 144 (44 of set 3) |             Carutapera, BR
# Skipping...  City (lasa, cn) is not found.
# Processing Record 145 (45 of set 3) |             Kozhva, RU
# Processing Record 146 (46 of set 3) |             Cayenne, GF
# Processing Record 147 (47 of set 3) |             Orcopampa, PE
# Processing Record 148 (48 of set 3) |             Mayo, CA
# Processing Record 149 (49 of set 3) |             San Quintin, MX
# Processing Record 150 (50 of set 3) |             Akdepe, TM
# Processing Record 151 (1 of set 4) |             Bontang, ID
# Processing Record 152 (2 of set 4) |             Fairbanks, US
# Processing Record 153 (3 of set 4) |             Tiksi, RU
# Processing Record 154 (4 of set 4) |             Bolekhiv, UA
# Processing Record 155 (5 of set 4) |             Kavieng, PG
# Skipping...  City (umzimvubu, za) is not found.
# Processing Record 156 (6 of set 4) |             Laguna, BR
# Processing Record 157 (7 of set 4) |             Jiangyou, CN
# Processing Record 158 (8 of set 4) |             Teahupoo, PF
# Processing Record 159 (9 of set 4) |             Margate, ZA
# Processing Record 160 (10 of set 4) |             Sennar, SD
# Processing Record 161 (11 of set 4) |             Ponta do Sol, PT
# Processing Record 162 (12 of set 4) |             Georgetown, SH
# Processing Record 163 (13 of set 4) |             Sembe, CG
# Processing Record 164 (14 of set 4) |             Cozumel, MX
# Processing Record 165 (15 of set 4) |             Patulul, GT
# Processing Record 166 (16 of set 4) |             Lorengau, PG
# Processing Record 167 (17 of set 4) |             Lompoc, US
# Processing Record 168 (18 of set 4) |             Grand Gaube, MU
# Processing Record 169 (19 of set 4) |             Ligayan, PH
# Processing Record 170 (20 of set 4) |             Burns Lake, CA
# Processing Record 171 (21 of set 4) |             Marrakesh, MA
# Processing Record 172 (22 of set 4) |             Walcz, PL
# Processing Record 173 (23 of set 4) |             Sokoni, TZ
# Processing Record 174 (24 of set 4) |             Walvis Bay, NA
# Processing Record 175 (25 of set 4) |             Price, US
# Processing Record 176 (26 of set 4) |             Mae Sot, TH
# Skipping...  City (grand river south east, mu) is not found.
# Processing Record 177 (27 of set 4) |             Rio Gallegos, AR
# Processing Record 178 (28 of set 4) |             Kismayo, SO
# Processing Record 179 (29 of set 4) |             Osakarovka, KZ
# Processing Record 180 (30 of set 4) |             Lagoa, PT
# Processing Record 181 (31 of set 4) |             College, US
# Processing Record 182 (32 of set 4) |             Cabo San Lucas, MX
# Processing Record 183 (33 of set 4) |             Souillac, MU
# Processing Record 184 (34 of set 4) |             Mitsamiouli, KM
# Processing Record 185 (35 of set 4) |             Naze, JP
# Processing Record 186 (36 of set 4) |             Kavaratti, IN
# Processing Record 187 (37 of set 4) |             Maragogi, BR
# Processing Record 188 (38 of set 4) |             Qaqortoq, GL
# Processing Record 189 (39 of set 4) |             Kudahuvadhoo, MV
# Processing Record 190 (40 of set 4) |             Huanuco, PE
# Processing Record 191 (41 of set 4) |             Palmer, US
# Processing Record 192 (42 of set 4) |             Bambanglipuro, ID
# Processing Record 193 (43 of set 4) |             Aasiaat, GL
# Processing Record 194 (44 of set 4) |             Saurimo, AO
# Processing Record 195 (45 of set 4) |             Sao Joao da Barra, BR
# Processing Record 196 (46 of set 4) |             Saskylakh, RU
# Processing Record 197 (47 of set 4) |             Bowen, AU
# Processing Record 198 (48 of set 4) |             Port Elizabeth, ZA
# Skipping...  City (burica, pa) is not found.
# Processing Record 199 (49 of set 4) |             Esim, GH
# Processing Record 200 (50 of set 4) |             Kodiak, US
# Processing Record 201 (1 of set 5) |             Luganville, VU
# Processing Record 202 (2 of set 5) |             Garissa, KE
# Processing Record 203 (3 of set 5) |             Melfi, TD
# Processing Record 204 (4 of set 5) |             Fortuna, US
# Processing Record 205 (5 of set 5) |             Sao Filipe, CV
# Processing Record 206 (6 of set 5) |             Arrondissement d'Ajaccio, FR
# Processing Record 207 (7 of set 5) |             Mogadishu, SO
# Processing Record 208 (8 of set 5) |             Poli, TZ
# Processing Record 209 (9 of set 5) |             Jacqueville, CI
# Processing Record 210 (10 of set 5) |             Yamada, JP
# Processing Record 211 (11 of set 5) |             Cap Malheureux, MU
# Processing Record 212 (12 of set 5) |             Geraldton, AU
# Processing Record 213 (13 of set 5) |             Thinadhoo, MV
# Processing Record 214 (14 of set 5) |             Barra, BR
# Processing Record 215 (15 of set 5) |             Olafsvik, IS
# Processing Record 216 (16 of set 5) |             Makakilo City, US
# Processing Record 217 (17 of set 5) |             Huayucachi, PE
# Processing Record 218 (18 of set 5) |             Chui, UY
# Processing Record 219 (19 of set 5) |             Port Blair, IN
# Processing Record 220 (20 of set 5) |             Oddur, SO
# Processing Record 221 (21 of set 5) |             Vytegra, RU
# Processing Record 222 (22 of set 5) |             Pinega, RU
# Skipping...  City (cockburn harbour, tc) is not found.
# Processing Record 223 (23 of set 5) |             Cockburn Town, TC
# Processing Record 224 (24 of set 5) |             Naduvattam, IN
# Processing Record 225 (25 of set 5) |             Mossamedes, AO
# Processing Record 226 (26 of set 5) |             Vila Velha, BR
# Processing Record 227 (27 of set 5) |             Bambous Virieux, MU
# Processing Record 228 (28 of set 5) |             Alofi, NU
# Processing Record 229 (29 of set 5) |             Castro, CL
# Skipping...  City (kargapolye, ru) is not found.
# Processing Record 230 (30 of set 5) |             Coquimbo, CL
# Processing Record 231 (31 of set 5) |             Bouloupari, NC
# Processing Record 232 (32 of set 5) |             Elk Point, CA
# Processing Record 233 (33 of set 5) |             Mecca, SA
# Processing Record 234 (34 of set 5) |             Barra de Tecoanapa, MX
# Processing Record 235 (35 of set 5) |             Kaduna, NG
# Processing Record 236 (36 of set 5) |             Bairiki Village, KI
# Processing Record 237 (37 of set 5) |             Chernyshevskiy, RU
# Processing Record 238 (38 of set 5) |             Mount Isa, AU
# Processing Record 239 (39 of set 5) |             Waliso, ET
# Processing Record 240 (40 of set 5) |             Bilma, NE
# Processing Record 241 (41 of set 5) |             Bure, ET
# Processing Record 242 (42 of set 5) |             Yanai, JP
# Processing Record 243 (43 of set 5) |             Ribeira Grande, PT
# Processing Record 244 (44 of set 5) |             Dalbandin, PK
# Processing Record 245 (45 of set 5) |             Acari, PE
# Processing Record 246 (46 of set 5) |             Thompson, CA
# Processing Record 247 (47 of set 5) |             Atlixco, MX
# Processing Record 248 (48 of set 5) |             Tessalit, ML
# Processing Record 249 (49 of set 5) |             Genhe, CN
# Processing Record 250 (50 of set 5) |             Kisanga, TZ
# Processing Record 251 (1 of set 6) |             Booue, GA
# Processing Record 252 (2 of set 6) |             Saint-Pierre, PM
# Processing Record 253 (3 of set 6) |             Grindavik, IS
# Processing Record 254 (4 of set 6) |             Plettenberg Bay, ZA
# Processing Record 255 (5 of set 6) |             Port Hedland, AU
# Processing Record 256 (6 of set 6) |             Te Anau, NZ
# Skipping...  City (kamenskoye, ru) is not found.
# Processing Record 257 (7 of set 6) |             Barcelos, BR
# Processing Record 258 (8 of set 6) |             Muisne, EC
# Skipping...  City (attawapiskat, ca) is not found.
# Processing Record 259 (9 of set 6) |             Ahipara, NZ
# Processing Record 260 (10 of set 6) |             Jati, PK
# Processing Record 261 (11 of set 6) |             Portree, GB
# Processing Record 262 (12 of set 6) |             Russell, NZ
# Processing Record 263 (13 of set 6) |             Buchanan, LR
# Processing Record 264 (14 of set 6) |             Mergen, CN
# Processing Record 265 (15 of set 6) |             Zaysan, KZ
# Processing Record 266 (16 of set 6) |             Moron, CU
# Processing Record 267 (17 of set 6) |             Carberry, CA
# Skipping...  City (fulitun, cn) is not found.
# Processing Record 268 (18 of set 6) |             Constitucion, CL
# Processing Record 269 (19 of set 6) |             Kibre Mengist, ET
# Processing Record 270 (20 of set 6) |             Devgarh, IN
# Processing Record 271 (21 of set 6) |             Xinmin, CN
# Processing Record 272 (22 of set 6) |             Puerto Madryn, AR
# Processing Record 273 (23 of set 6) |             Ko Samui, TH
# Processing Record 274 (24 of set 6) |             Severo-Kuril'sk, RU
# Processing Record 275 (25 of set 6) |             Hofn, IS
# Processing Record 276 (26 of set 6) |             Salalah, OM
# Processing Record 277 (27 of set 6) |             Poum, NC
# Processing Record 278 (28 of set 6) |             Murray Bridge, AU
# Processing Record 279 (29 of set 6) |             Woodbury, US
# Processing Record 280 (30 of set 6) |             Bafra, TR
# Processing Record 281 (31 of set 6) |             Broome, AU
# Processing Record 282 (32 of set 6) |             Fiumicino, IT
# Processing Record 283 (33 of set 6) |             Srednekolymsk, RU
# Skipping...  City (kleck, by) is not found.
# Processing Record 284 (34 of set 6) |             Kautokeino, NO
# Skipping...  City (wahran, dz) is not found.
# Processing Record 285 (35 of set 6) |             Comodoro Rivadavia, AR
# Processing Record 286 (36 of set 6) |             Cidreira, BR
# Skipping...  City (toliary, mg) is not found.
# Processing Record 287 (37 of set 6) |             Middelburg, ZA
# Processing Record 288 (38 of set 6) |             Nar'yan-Mar, RU
# Processing Record 289 (39 of set 6) |             Torbay, CA
# Processing Record 290 (40 of set 6) |             Ust-Tsilma, RU
# Processing Record 291 (41 of set 6) |             Mumford, GH
# Processing Record 292 (42 of set 6) |             Condado, CU
# Processing Record 293 (43 of set 6) |             Port Hawkesbury, CA
# Skipping...  City (tabiauea, ki) is not found.
# Processing Record 294 (44 of set 6) |             Mersa Matruh, EG
# Processing Record 295 (45 of set 6) |             Haines Junction, CA
# Processing Record 296 (46 of set 6) |             Ancud, CL
# Skipping...  City (mankovo-kalitvenskoye, ru) is not found.
# Processing Record 297 (47 of set 6) |             Paraiso, MX
# Processing Record 298 (48 of set 6) |             Camacha, PT
# Processing Record 299 (49 of set 6) |             Baracoa, CU
# Processing Record 300 (50 of set 6) |             Oruzgan, AF
# Processing Record 301 (1 of set 7) |             Kumul, CN
# Processing Record 302 (2 of set 7) |             Rexburg, US
# Skipping...  City (bereda, so) is not found.
# Processing Record 303 (3 of set 7) |             Yanzhou, CN
# Processing Record 304 (4 of set 7) |             Salinas, EC
# Skipping...  City (dinsor, so) is not found.
# Skipping...  City (samusu, ws) is not found.
# Processing Record 305 (5 of set 7) |             Hamilton, BM
# Processing Record 306 (6 of set 7) |             Ballina, AU
# Processing Record 307 (7 of set 7) |             Huarmey, PE
# Processing Record 308 (8 of set 7) |             Sao Felix do Xingu, BR
# Processing Record 309 (9 of set 7) |             Soma, TR
# Processing Record 310 (10 of set 7) |             Tuktoyaktuk, CA
# Skipping...  City (saint anthony, ca) is not found.
# Processing Record 311 (11 of set 7) |             Varhaug, NO
# Processing Record 312 (12 of set 7) |             Dragor, DK
# Processing Record 313 (13 of set 7) |             Tilichiki, RU
# Processing Record 314 (14 of set 7) |             Shenjiamen, CN
# Processing Record 315 (15 of set 7) |             Kahului, US
# Processing Record 316 (16 of set 7) |             Longyearbyen, SJ
# Processing Record 317 (17 of set 7) |             Kodinsk, RU
# Processing Record 318 (18 of set 7) |             Bengkulu, ID
# Processing Record 319 (19 of set 7) |             Fafe, PT
# Processing Record 320 (20 of set 7) |             Labuhan, ID
# Processing Record 321 (21 of set 7) |             Mount Gambier, AU
# Processing Record 322 (22 of set 7) |             Sechura, PE
# Processing Record 323 (23 of set 7) |             Fort Morgan, US
# Processing Record 324 (24 of set 7) |             Evensk, RU
# Skipping...  City (redcliffe, zw) is not found.
# Processing Record 325 (25 of set 7) |             Fayaoue, NC
# Processing Record 326 (26 of set 7) |             Shaowu, CN
# Processing Record 327 (27 of set 7) |             Rawson, AR
# Processing Record 328 (28 of set 7) |             Pangnirtung, CA
# Skipping...  City (ye, mm) is not found.
# Processing Record 329 (29 of set 7) |             Narrabri, AU
# Processing Record 330 (30 of set 7) |             Okhotsk, RU
# Processing Record 331 (31 of set 7) |             Jamkhed, IN
# Processing Record 332 (32 of set 7) |             Snaase, NO
# Skipping...  City (yaan, cn) is not found.
# Processing Record 333 (33 of set 7) |             Pitea, SE
# Processing Record 334 (34 of set 7) |             Pandan, PH
# Processing Record 335 (35 of set 7) |             Tabas, IR
# Processing Record 336 (36 of set 7) |             Cabedelo, BR
# Processing Record 337 (37 of set 7) |             Nome, US
# Processing Record 338 (38 of set 7) |             Port Pirie, AU
# Processing Record 339 (39 of set 7) |             San Cristobal, EC
# Processing Record 340 (40 of set 7) |             Deputatsky, RU
# Processing Record 341 (41 of set 7) |             Langxiang, CN
# Processing Record 342 (42 of set 7) |             Banyo, CM
# Processing Record 343 (43 of set 7) |             Saint George, BM
# Processing Record 344 (44 of set 7) |             Ambovombe, MG
# Processing Record 345 (45 of set 7) |             Shimabara, JP
# Skipping...  City (lolua, tv) is not found.
# Processing Record 346 (46 of set 7) |             Bagdarin, RU
# Processing Record 347 (47 of set 7) |             Namatanai, PG
# Processing Record 348 (48 of set 7) |             Klyuchevsk, RU
# Processing Record 349 (49 of set 7) |             Naples, US
# Processing Record 350 (50 of set 7) |             Sesheke, ZM
# Processing Record 351 (1 of set 8) |             Emba, KZ
# Processing Record 352 (2 of set 8) |             Neiafu, TO
# Processing Record 353 (3 of set 8) |             Batagay-Alyta, RU
# Processing Record 354 (4 of set 8) |             Mexico, US
# Processing Record 355 (5 of set 8) |             Yining, CN
# Processing Record 356 (6 of set 8) |             Bucarasica, CO
# Processing Record 357 (7 of set 8) |             Lavrentiya, RU
# Processing Record 358 (8 of set 8) |             Xai-Xai, MZ
# Processing Record 359 (9 of set 8) |             Hofgeismar, DE
# Skipping...  City (ginda, er) is not found.
# Processing Record 360 (10 of set 8) |             Tukrah, LY
# Processing Record 361 (11 of set 8) |             Syracuse, IT
# Processing Record 362 (12 of set 8) |             Westport, NZ
# Processing Record 363 (13 of set 8) |             Coracora, PE
# Processing Record 364 (14 of set 8) |             Bodinayakkanur, IN
# Processing Record 365 (15 of set 8) |             Salekhard, RU
# Processing Record 366 (16 of set 8) |             Kano, NG
# Processing Record 367 (17 of set 8) |             Bandarbeyla, SO
# Processing Record 368 (18 of set 8) |             Nelas, PT
# Processing Record 369 (19 of set 8) |             Shingu, JP
# Processing Record 370 (20 of set 8) |             Rockport, US
# Processing Record 371 (21 of set 8) |             Kloulklubed, PW
# Skipping...  City (saleaula, ws) is not found.
# Processing Record 372 (22 of set 8) |             Itaqui, BR
# Processing Record 373 (23 of set 8) |             Chabahar, IR
# Processing Record 374 (24 of set 8) |             Lincoln, AR
# Processing Record 375 (25 of set 8) |             Ust'-Ishim, RU
# Processing Record 376 (26 of set 8) |             Brownsville, US
# Processing Record 377 (27 of set 8) |             Jining, CN
# Processing Record 378 (28 of set 8) |             La Orilla, MX
# Processing Record 379 (29 of set 8) |             Agadir, MA
# Processing Record 380 (30 of set 8) |             Flin Flon, CA
# Processing Record 381 (31 of set 8) |             Dingle, IE
# Processing Record 382 (32 of set 8) |             Oriximina, BR
# Processing Record 383 (33 of set 8) |             Guerrero Negro, MX
# Processing Record 384 (34 of set 8) |             La Romana, DO
# Processing Record 385 (35 of set 8) |             Saran, FR
# Processing Record 386 (36 of set 8) |             Manokwari, ID
# Processing Record 387 (37 of set 8) |             Puerto Escondido, MX
# Processing Record 388 (38 of set 8) |             Melilla, ES
# Processing Record 389 (39 of set 8) |             Halifax, CA
# Processing Record 390 (40 of set 8) |             Sabang, ID
# Skipping...  City (palabuhanratu, id) is not found.
# Processing Record 391 (41 of set 8) |             Hirara, JP
# Processing Record 392 (42 of set 8) |             Rovaniemi, FI
# Skipping...  City (ambodifototra, mg) is not found.
# Processing Record 393 (43 of set 8) |             Kousseri, CM
# Processing Record 394 (44 of set 8) |             Zapadnaya Dvina, RU
# Processing Record 395 (45 of set 8) |             Strezhevoy, RU
# Processing Record 396 (46 of set 8) |             Kirovo-Chepetsk, RU
# Processing Record 397 (47 of set 8) |             Sao Joao dos Patos, BR
# Processing Record 398 (48 of set 8) |             Nabire, ID
# Processing Record 399 (49 of set 8) |             Bhinmal, IN
# Processing Record 400 (50 of set 8) |             Yanam, IN
# Processing Record 401 (1 of set 9) |             Chegdomyn, RU
# Processing Record 402 (2 of set 9) |             Raudeberg, NO
# Processing Record 403 (3 of set 9) |             Khandyga, RU
# Processing Record 404 (4 of set 9) |             Cabra, PH
# Processing Record 405 (5 of set 9) |             Raton, US
# Processing Record 406 (6 of set 9) |             Novo Aripuana, BR
# Processing Record 407 (7 of set 9) |             Ostrovnoy, RU
# Processing Record 408 (8 of set 9) |             Los Andes, CL
# Processing Record 409 (9 of set 9) |             Sampit, ID
# Processing Record 410 (10 of set 9) |             Phalodi, IN
# Processing Record 411 (11 of set 9) |             Gaya, NE
# Processing Record 412 (12 of set 9) |             Denpasar, ID
# Processing Record 413 (13 of set 9) |             Hit, IQ
# Processing Record 414 (14 of set 9) |             Mormugao, IN
# Processing Record 415 (15 of set 9) |             Portage, US
# Processing Record 416 (16 of set 9) |             Altay, CN
# Processing Record 417 (17 of set 9) |             La Ronge, CA
# Processing Record 418 (18 of set 9) |             Kasongo, CD
# Processing Record 419 (19 of set 9) |             Kirakira, SB
# Processing Record 420 (20 of set 9) |             Aguas Vermelhas, BR
# Processing Record 421 (21 of set 9) |             Darlowo, PL
# Processing Record 422 (22 of set 9) |             Ambon, ID
# Processing Record 423 (23 of set 9) |             Antofagasta, CL
# Processing Record 424 (24 of set 9) |             Vestmannaeyjar, IS
# Processing Record 425 (25 of set 9) |             Tucurui, BR
# Skipping...  City (codrington, ag) is not found.
# Processing Record 426 (26 of set 9) |             Okha, RU
# Processing Record 427 (27 of set 9) |             Quatre Cocos, MU
# Processing Record 428 (28 of set 9) |             Qasigiannguit, GL
# Processing Record 429 (29 of set 9) |             Khartoum, SD
# Processing Record 430 (30 of set 9) |             Sur, OM
# Processing Record 431 (31 of set 9) |             Kashan, IR
# Processing Record 432 (32 of set 9) |             Tazovsky, RU
# Processing Record 433 (33 of set 9) |             Gornopravdinsk, RU
# Processing Record 434 (34 of set 9) |             Arrondissement de Torcy, FR
# Processing Record 435 (35 of set 9) |             Uusikaupunki, FI
# Processing Record 436 (36 of set 9) |             Bismarck, US
# Processing Record 437 (37 of set 9) |             Auki, SB
# Processing Record 438 (38 of set 9) |             Ingham, AU
# Processing Record 439 (39 of set 9) |             Kilindoni, TZ
# Processing Record 440 (40 of set 9) |             Yerbogachen, RU
# Processing Record 441 (41 of set 9) |             Gelibolu, TR
# Processing Record 442 (42 of set 9) |             Chatrapur, IN
# Processing Record 443 (43 of set 9) |             Essex, CA
# Processing Record 444 (44 of set 9) |             Alanya, TR
# Processing Record 445 (45 of set 9) |             Shelburne, CA
# Processing Record 446 (46 of set 9) |             Cabanas, CU
# Processing Record 447 (47 of set 9) |             Murupara, NZ
# Processing Record 448 (48 of set 9) |             Troitskoye, RU
# Processing Record 449 (49 of set 9) |             Avanuorri, NO
# Processing Record 450 (50 of set 9) |             Pasni, PK
# Processing Record 451 (1 of set 10) |             Samana, DO
# Processing Record 452 (2 of set 10) |             Broken Hill, AU
# Processing Record 453 (3 of set 10) |             Digapahandi, IN
# Processing Record 454 (4 of set 10) |             Lampa, CL
# Processing Record 455 (5 of set 10) |             Vodstroy, RU
# Processing Record 456 (6 of set 10) |             Nizhniy Kuranakh, RU
# Processing Record 457 (7 of set 10) |             Foshan, CN
# Processing Record 458 (8 of set 10) |             Khromtau, KZ
# Processing Record 459 (9 of set 10) |             Bela, PK
# Processing Record 460 (10 of set 10) |             Lakatoro, VU
# Processing Record 461 (11 of set 10) |             Amapa, BR
# Processing Record 462 (12 of set 10) |             Padang, ID
# Processing Record 463 (13 of set 10) |             Nimes, FR
# Processing Record 464 (14 of set 10) |             Nandu, CN
# Processing Record 465 (15 of set 10) |             Kondinskoye, RU
# Processing Record 466 (16 of set 10) |             Sola, VU
# Processing Record 467 (17 of set 10) |             Brandfort, ZA
# Processing Record 468 (18 of set 10) |             Boa Vista, BR
# Processing Record 469 (19 of set 10) |             Ternate, ID
# Processing Record 470 (20 of set 10) |             Bani Walid, LY
# Processing Record 471 (21 of set 10) |             Hobyo, SO
# Processing Record 472 (22 of set 10) |             Mandalgovi, MN
# Processing Record 473 (23 of set 10) |             Catuday, PH
# Processing Record 474 (24 of set 10) |             Honghu, CN
# Processing Record 475 (25 of set 10) |             Atasu, KZ
# Processing Record 476 (26 of set 10) |             Hendrina, ZA
# Processing Record 477 (27 of set 10) |             Vaitape, PF
# Processing Record 478 (28 of set 10) |             Hambantota, LK
# Processing Record 479 (29 of set 10) |             Nemuro, JP
# Processing Record 480 (30 of set 10) |             Kushmurun, KZ
# Processing Record 481 (31 of set 10) |             Pocerski Pricinovic, RS
# Processing Record 482 (32 of set 10) |             Sao Cristovao, BR
# Processing Record 483 (33 of set 10) |             Kedougou, SN
# Processing Record 484 (34 of set 10) |             Baghdad, IQ
# Skipping...  City (garm, tj) is not found.
# Processing Record 485 (35 of set 10) |             Sagaing, MM
# Processing Record 486 (36 of set 10) |             San Luis, PE
# Processing Record 487 (37 of set 10) |             Belaya Gora, RU
# Processing Record 488 (38 of set 10) |             Dakar, SN
# Processing Record 489 (39 of set 10) |             San Fernando, MX
# Processing Record 490 (40 of set 10) |             Shaunavon, CA
# Processing Record 491 (41 of set 10) |             Beni, CD
# Processing Record 492 (42 of set 10) |             Mastic Beach, US
# Processing Record 493 (43 of set 10) |             Komsomolskiy, RU
# Processing Record 494 (44 of set 10) |             Dukat, RU
# Processing Record 495 (45 of set 10) |             Tabou, CI
# Processing Record 496 (46 of set 10) |             Moose Factory, CA
# Processing Record 497 (47 of set 10) |             Beira, MZ
# Processing Record 498 (48 of set 10) |             Monticello, US
# Processing Record 499 (49 of set 10) |             Hjallerup, DK
# Processing Record 500 (50 of set 10) |             Suhut, TR
# Processing Record 501 (1 of set 11) |             Tharad, IN
# Processing Record 502 (2 of set 11) |             Hay River, CA
# Processing Record 503 (3 of set 11) |             Luena, AO
# Processing Record 504 (4 of set 11) |             Reconquista, AR
# Processing Record 505 (5 of set 11) |             Revelstoke, CA
# Processing Record 506 (6 of set 11) |             Roma, AU
# Processing Record 507 (7 of set 11) |             Biberach an der Riss, DE
# Processing Record 508 (8 of set 11) |             Sovetskiy, RU
# Processing Record 509 (9 of set 11) |             Esperance, AU
# Processing Record 510 (10 of set 11) |             Bathsheba, BB
# Processing Record 511 (11 of set 11) |             Sakakah, SA
# Processing Record 512 (12 of set 11) |             Porbandar, IN
# Processing Record 513 (13 of set 11) |             Camar, RO
# Processing Record 514 (14 of set 11) |             Mildura, AU
# Skipping...  City (marcona, pe) is not found.
# Processing Record 515 (15 of set 11) |             Conceicao do Araguaia, BR
# Processing Record 516 (16 of set 11) |             Keti Bandar, PK
# Processing Record 517 (17 of set 11) |             Methven, NZ
# Processing Record 518 (18 of set 11) |             Herat, AF
# Processing Record 519 (19 of set 11) |             Hobbs, US
# Processing Record 520 (20 of set 11) |             Inirida, CO
# Processing Record 521 (21 of set 11) |             Dunedin, NZ
# Processing Record 522 (22 of set 11) |             Charters Towers, AU
# Processing Record 523 (23 of set 11) |             Talnakh, RU
# Processing Record 524 (24 of set 11) |             Fare, PF
# Processing Record 525 (25 of set 11) |             Pauini, BR
# Skipping...  City (oga, jp) is not found.
# Processing Record 526 (26 of set 11) |             Isangel, VU
# Processing Record 527 (27 of set 11) |             Fort Nelson, CA
# Processing Record 528 (28 of set 11) |             Riverton, US
# Processing Record 529 (29 of set 11) |             Le Vauclin, MQ
# Processing Record 530 (30 of set 11) |             Sergiyev Posad, RU
# Processing Record 531 (31 of set 11) |             Rawlins, US
# Processing Record 532 (32 of set 11) |             Erdenet, MN
# Processing Record 533 (33 of set 11) |             Zhigansk, RU
# Processing Record 534 (34 of set 11) |             Loviisa, FI
# Processing Record 535 (35 of set 11) |             Camacari, BR
# Processing Record 536 (36 of set 11) |             Nizhnevartovsk, RU
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
# weather_data

# Print the json (pretty printed)
# print(json.dumps(weather_data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 1
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 31.58,
#             "lon": -90.44
#         },
#         "dt": 1579910962,
#         "id": 4419500,
#         "main": {
#             "feels_like": 46.35,
#             "humidity": 44,
#             "pressure": 1018,
#             "temp": 52.66,
#             "temp_max": 57.2,
#             "temp_min": 48.99
#         },
#         "name": "Brookhaven",
#         "sys": {
#             "country": "US",
#             "id": 2672,
#             "sunrise": 1579870742,
#             "sunset": 1579908490,
#             "type": 1
#         },
#         "timezone": -21600,
#         "visibility": 9656,
#         "weather": [
#             {
#                 "description": "haze",
#                 "icon": "50n",
#                 "id": 721,
#                 "main": "Haze"
#             }
#         ],
#         "wind": {
#             "deg": 310,
#             "speed": 4.7
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 85
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 72.79,
#             "lon": -56.15
#         },
#         "dt": 1579910962,
#         "id": 3418910,
#         "main": {
#             "feels_like": -23.51,
#             "grnd_level": 998,
#             "humidity": 95,
#             "pressure": 998,
#             "sea_level": 998,
#             "temp": -14.37,
#             "temp_max": -14.37,
#             "temp_min": -14.37
#         },
#         "name": "Upernavik",
#         "sys": {
#             "country": "GL",
#             "sunrise": 0,
#             "sunset": 0
#         },
#         "timezone": -10800,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04n",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 349,
#             "speed": 4.21
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 54
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -5.55,
#             "lon": 150.14
#         },
#         "dt": 1579910963,
#         "id": 2093967,
#         "main": {
#             "feels_like": 92.91,
#             "grnd_level": 997,
#             "humidity": 66,
#             "pressure": 1010,
#             "sea_level": 1010,
#             "temp": 86,
#             "temp_max": 86,
#             "temp_min": 86
#         },
#         "name": "Kimbe",
#         "rain": {
#             "3h": 0.13
#         },
#         "sys": {
#             "country": "PG",
#             "sunrise": 1579896004,
#             "sunset": 1579940559
#         },
#         "timezone": 36000,
#         "weather": [
#             {
#                 "description": "light rain",
#                 "icon": "10d",
#                 "id": 500,
#                 "main": "Rain"
#             }
#         ],
#         "wind": {
#             "deg": 297,
#             "speed": 4.38
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 100
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 50.75,
#             "lon": 31.38
#         },
#         "dt": 1579910963,
#         "id": 711999,
#         "main": {
#             "feels_like": 24.84,
#             "humidity": 69,
#             "pressure": 1014,
#             "temp": 34.32,
#             "temp_max": 35.01,
#             "temp_min": 33.8
#         },
#         "name": "Bobrovytsya",
#         "sys": {
#             "country": "UA",
#             "id": 8898,
#             "sunrise": 1579930846,
#             "sunset": 1579962732,
#             "type": 1
#         },
#         "timezone": 7200,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04n",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 280,
#             "speed": 8.95
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 75
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 64.57,
#             "lon": 143.2
#         },
#         "dt": 1579910963,
#         "id": 2120048,
#         "main": {
#             "feels_like": -55.48,
#             "grnd_level": 899,
#             "humidity": 100,
#             "pressure": 1036,
#             "sea_level": 1036,
#             "temp": -47.87,
#             "temp_max": -47.87,
#             "temp_min": -47.87
#         },
#         "name": "Ust-Nera",
#         "sys": {
#             "country": "RU",
#             "sunrise": 1579908937,
#             "sunset": 1579930958
#         },
#         "timezone": 36000,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04d",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 273,
#             "speed": 0.85
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 69
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -13.7,
#             "lon": -76.22
#         },
#         "dt": 1579910845,
#         "id": 3932145,
#         "main": {
#             "feels_like": 63.5,
#             "humidity": 30,
#             "pressure": 1012,
#             "temp": 72.32,
#             "temp_max": 73,
#             "temp_min": 71.6
#         },
#         "name": "Pisco",
#         "sys": {
#             "country": "PE",
#             "id": 8691,
#             "sunrise": 1579863210,
#             "sunset": 1579909195,
#             "type": 1
#         },
#         "timezone": -18000,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04n",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 220,
#             "speed": 11.41
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 100
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 69.22,
#             "lon": -51.1
#         },
#         "dt": 1579910964,
#         "id": 3423146,
#         "main": {
#             "feels_like": 1.74,
#             "humidity": 52,
#             "pressure": 992,
#             "temp": 15.8,
#             "temp_max": 15.8,
#             "temp_min": 15.8
#         },
#         "name": "Ilulissat",
#         "sys": {
#             "country": "GL",
#             "id": 165,
#             "sunrise": 1579873354,
#             "sunset": 1579886991,
#             "type": 1
#         },
#         "timezone": -10800,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04n",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 110,
#             "speed": 13.87
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 20
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -0.74,
#             "lon": -90.35
#         },
#         "dt": 1579910763,
#         "id": 3652764,
#         "main": {
#             "feels_like": 78.15,
#             "humidity": 62,
#             "pressure": 1010,
#             "temp": 80.67,
#             "temp_max": 84.2,
#             "temp_min": 78.01
#         },
#         "name": "Puerto Ayora",
#         "sys": {
#             "country": "EC",
#             "id": 8521,
#             "sunrise": 1579867721,
#             "sunset": 1579911467,
#             "type": 1
#         },
#         "timezone": -21600,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "few clouds",
#                 "icon": "02d",
#                 "id": 801,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 130,
#             "speed": 14.99
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 34
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -41.41,
#             "lon": 175.52
#         },
#         "dt": 1579910964,
#         "id": 2206874,
#         "main": {
#             "feels_like": 59.11,
#             "humidity": 64,
#             "pressure": 1015,
#             "temp": 70.79,
#             "temp_max": 73,
#             "temp_min": 69.01
#         },
#         "name": "Waipawa",
#         "sys": {
#             "country": "NZ",
#             "id": 7358,
#             "sunrise": 1579885998,
#             "sunset": 1579938381,
#             "type": 1
#         },
#         "timezone": 46800,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "scattered clouds",
#                 "icon": "03d",
#                 "id": 802,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 360,
#             "speed": 25.28
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 75
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -54.8,
#             "lon": -68.3
#         },
#         "dt": 1579910761,
#         "id": 3833367,
#         "main": {
#             "feels_like": 49.15,
#             "humidity": 76,
#             "pressure": 996,
#             "temp": 51.8,
#             "temp_max": 51.8,
#             "temp_min": 51.8
#         },
#         "name": "Ushuaia",
#         "sys": {
#             "country": "AR",
#             "id": 8303,
#             "sunrise": 1579855138,
#             "sunset": 1579913465,
#             "type": 1
#         },
#         "timezone": -10800,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04d",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 133,
#             "speed": 2.42
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 40
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -53.15,
#             "lon": -70.92
#         },
#         "dt": 1579910774,
#         "id": 3874787,
#         "main": {
#             "feels_like": 40.14,
#             "humidity": 76,
#             "pressure": 999,
#             "temp": 49.15,
#             "temp_max": 50,
#             "temp_min": 48.2
#         },
#         "name": "Punta Arenas",
#         "sys": {
#             "country": "CL",
#             "id": 8487,
#             "sunrise": 1579856249,
#             "sunset": 1579913611,
#             "type": 1
#         },
#         "timezone": -10800,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "scattered clouds",
#                 "icon": "03d",
#                 "id": 802,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 260,
#             "speed": 12.75
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 93
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 65.85,
#             "lon": 74.49
#         },
#         "dt": 1579910964,
#         "id": 1495626,
#         "main": {
#             "feels_like": -3.15,
#             "grnd_level": 979,
#             "humidity": 96,
#             "pressure": 987,
#             "sea_level": 987,
#             "temp": 4.78,
#             "temp_max": 4.78,
#             "temp_min": 4.78
#         },
#         "name": "Pangody",
#         "snow": {
#             "3h": 0.13
#         },
#         "sys": {
#             "country": "RU",
#             "sunrise": 1579926229,
#             "sunset": 1579946653
#         },
#         "timezone": 18000,
#         "weather": [
#             {
#                 "description": "light snow",
#                 "icon": "13n",
#                 "id": 600,
#                 "main": "Snow"
#             }
#         ],
#         "wind": {
#             "deg": 222,
#             "speed": 3.22
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 100
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 68.23,
#             "lon": 14.57
#         },
#         "dt": 1579910964,
#         "id": 3135020,
#         "main": {
#             "feels_like": 25.68,
#             "humidity": 86,
#             "pressure": 987,
#             "temp": 33.01,
#             "temp_max": 33.01,
#             "temp_min": 33.01
#         },
#         "name": "Svolvaer",
#         "snow": {
#             "3h": 0.81
#         },
#         "sys": {
#             "country": "NO",
#             "id": 2006543,
#             "sunrise": 1579942586,
#             "sunset": 1579959062,
#             "type": 3
#         },
#         "timezone": 3600,
#         "weather": [
#             {
#                 "description": "light snow",
#                 "icon": "13n",
#                 "id": 600,
#                 "main": "Snow"
#             }
#         ],
#         "wind": {
#             "deg": 205,
#             "speed": 5.99
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 75
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 36.01,
#             "lon": -5.61
#         },
#         "dt": 1579910965,
#         "id": 2510599,
#         "main": {
#             "feels_like": 51.87,
#             "humidity": 76,
#             "pressure": 1018,
#             "temp": 56.07,
#             "temp_max": 57.2,
#             "temp_min": 53.6
#         },
#         "name": "Tarifa",
#         "sys": {
#             "country": "ES",
#             "id": 2416,
#             "sunrise": 1579937296,
#             "sunset": 1579974041,
#             "type": 1
#         },
#         "timezone": 3600,
#         "visibility": 8000,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04n",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 150,
#             "speed": 6.93
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 86
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -46.28,
#             "lon": 169.85
#         },
#         "dt": 1579910801,
#         "id": 2208248,
#         "main": {
#             "feels_like": 51.57,
#             "grnd_level": 1013,
#             "humidity": 92,
#             "pressure": 1013,
#             "sea_level": 1013,
#             "temp": 57.51,
#             "temp_max": 57.51,
#             "temp_min": 57.51
#         },
#         "name": "Kaitangata",
#         "rain": {
#             "3h": 0.44
#         },
#         "sys": {
#             "country": "NZ",
#             "sunrise": 1579886494,
#             "sunset": 1579940607
#         },
#         "timezone": 46800,
#         "weather": [
#             {
#                 "description": "light rain",
#                 "icon": "10d",
#                 "id": 500,
#                 "main": "Rain"
#             }
#         ],
#         "wind": {
#             "deg": 214,
#             "speed": 13.42
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 79
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -46.6,
#             "lon": 168.33
#         },
#         "dt": 1579910765,
#         "id": 2206939,
#         "main": {
#             "feels_like": 61.72,
#             "humidity": 72,
#             "pressure": 1016,
#             "temp": 64.99,
#             "temp_max": 64.99,
#             "temp_min": 64.99
#         },
#         "name": "Bluff",
#         "rain": {
#             "3h": 0.25
#         },
#         "sys": {
#             "country": "NZ",
#             "id": 2008959,
#             "sunrise": 1579886796,
#             "sunset": 1579941035,
#             "type": 3
#         },
#         "timezone": 46800,
#         "weather": [
#             {
#                 "description": "light rain",
#                 "icon": "10d",
#                 "id": 500,
#                 "main": "Rain"
#             }
#         ],
#         "wind": {
#             "deg": 220,
#             "gust": 18.99,
#             "speed": 8.99
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 73
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 71.97,
#             "lon": 102.5
#         },
#         "dt": 1579910802,
#         "id": 2022572,
#         "main": {
#             "feels_like": -35.72,
#             "grnd_level": 997,
#             "humidity": 89,
#             "pressure": 1001,
#             "sea_level": 1001,
#             "temp": -23.94,
#             "temp_max": -23.94,
#             "temp_min": -23.94
#         },
#         "name": "Khatanga",
#         "sys": {
#             "country": "RU",
#             "sunrise": 0,
#             "sunset": 0
#         },
#         "timezone": 25200,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04n",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 92,
#             "speed": 8.55
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 0
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -26.65,
#             "lon": 15.16
#         },
#         "dt": 1579910815,
#         "id": 3355672,
#         "main": {
#             "feels_like": 70.34,
#             "humidity": 88,
#             "pressure": 1014,
#             "temp": 68,
#             "temp_max": 68,
#             "temp_min": 68
#         },
#         "name": "Luderitz",
#         "sys": {
#             "country": "NA",
#             "id": 2260,
#             "sunrise": 1579926440,
#             "sunset": 1579974925,
#             "type": 1
#         },
#         "timezone": 7200,
#         "weather": [
#             {
#                 "description": "clear sky",
#                 "icon": "01n",
#                 "id": 800,
#                 "main": "Clear"
#             }
#         ],
#         "wind": {
#             "deg": 170,
#             "speed": 4.7
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 20
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -21.2,
#             "lon": -175.2
#         },
#         "dt": 1579910780,
#         "id": 4032243,
#         "main": {
#             "feels_like": 85.78,
#             "humidity": 70,
#             "pressure": 1010,
#             "temp": 84.2,
#             "temp_max": 84.2,
#             "temp_min": 84.2
#         },
#         "name": "Vaini",
#         "sys": {
#             "country": "TO",
#             "id": 7285,
#             "sunrise": 1579972709,
#             "sunset": 1580020044,
#             "type": 1
#         },
#         "timezone": 46800,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "few clouds",
#                 "icon": "02n",
#                 "id": 801,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 110,
#             "speed": 13.87
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 0
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -34.42,
#             "lon": 19.23
#         },
#         "dt": 1579910782,
#         "id": 3366880,
#         "main": {
#             "feels_like": 64.53,
#             "humidity": 95,
#             "pressure": 1007,
#             "temp": 65.35,
#             "temp_max": 66.99,
#             "temp_min": 64
#         },
#         "name": "Hermanus",
#         "sys": {
#             "country": "ZA",
#             "id": 2006131,
#             "sunrise": 1579924546,
#             "sunset": 1579974865,
#             "type": 3
#         },
#         "timezone": 7200,
#         "weather": [
#             {
#                 "description": "clear sky",
#                 "icon": "01n",
#                 "id": 800,
#                 "main": "Clear"
#             }
#         ],
#         "wind": {
#             "deg": 111,
#             "speed": 10.02
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 75
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -20.41,
#             "lon": 57.7
#         },
#         "dt": 1579910802,
#         "id": 934322,
#         "main": {
#             "feels_like": 83.7,
#             "humidity": 100,
#             "pressure": 1000,
#             "temp": 78.42,
#             "temp_max": 80.01,
#             "temp_min": 77
#         },
#         "name": "Mahebourg",
#         "sys": {
#             "country": "MU",
#             "id": 2061,
#             "sunrise": 1579916864,
#             "sunset": 1579964078,
#             "type": 1
#         },
#         "timezone": 14400,
#         "visibility": 8000,
#         "weather": [
#             {
#                 "description": "shower rain",
#                 "icon": "09n",
#                 "id": 521,
#                 "main": "Rain"
#             }
#         ],
#         "wind": {
#             "deg": 180,
#             "speed": 12.75
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 97
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 66.56,
#             "lon": 67.8
#         },
#         "dt": 1579910965,
#         "id": 1512019,
#         "main": {
#             "feels_like": -6.59,
#             "grnd_level": 981,
#             "humidity": 96,
#             "pressure": 987,
#             "sea_level": 987,
#             "temp": 2.05,
#             "temp_max": 2.05,
#             "temp_min": 2.05
#         },
#         "name": "Aksarka",
#         "snow": {
#             "3h": 0.13
#         },
#         "sys": {
#             "country": "RU",
#             "sunrise": 1579928357,
#             "sunset": 1579947736
#         },
#         "timezone": 18000,
#         "weather": [
#             {
#                 "description": "light snow",
#                 "icon": "13n",
#                 "id": 600,
#                 "main": "Snow"
#             }
#         ],
#         "wind": {
#             "deg": 24,
#             "speed": 4.25
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 75
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 35.13,
#             "lon": 140.3
#         },
#         "dt": 1579910966,
#         "id": 2112309,
#         "main": {
#             "feels_like": 36.25,
#             "humidity": 69,
#             "pressure": 1028,
#             "temp": 45.07,
#             "temp_max": 48,
#             "temp_min": 41
#         },
#         "name": "Katsuura",
#         "sys": {
#             "country": "JP",
#             "id": 8074,
#             "sunrise": 1579902180,
#             "sunset": 1579939108,
#             "type": 1
#         },
#         "timezone": 32400,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04d",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 50,
#             "speed": 10.29
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 29
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -33.65,
#             "lon": 115.33
#         },
#         "dt": 1579910643,
#         "id": 2075265,
#         "main": {
#             "feels_like": 67.71,
#             "humidity": 76,
#             "pressure": 1017,
#             "temp": 66.99,
#             "temp_max": 66.99,
#             "temp_min": 66.99
#         },
#         "name": "Busselton",
#         "sys": {
#             "country": "AU",
#             "id": 2003721,
#             "sunrise": 1579901565,
#             "sunset": 1579951710,
#             "type": 3
#         },
#         "timezone": 28800,
#         "weather": [
#             {
#                 "description": "scattered clouds",
#                 "icon": "03d",
#                 "id": 802,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 157,
#             "gust": 8.99,
#             "speed": 4
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 100
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -25.53,
#             "lon": 152.7
#         },
#         "dt": 1579910966,
#         "id": 2158562,
#         "main": {
#             "feels_like": 87.57,
#             "grnd_level": 1005,
#             "humidity": 77,
#             "pressure": 1013,
#             "sea_level": 1013,
#             "temp": 81.21,
#             "temp_max": 81.21,
#             "temp_min": 81.21
#         },
#         "name": "Maryborough",
#         "rain": {
#             "3h": 0.31
#         },
#         "sys": {
#             "country": "AU",
#             "sunrise": 1579893533,
#             "sunset": 1579941802
#         },
#         "timezone": 36000,
#         "weather": [
#             {
#                 "description": "light rain",
#                 "icon": "10d",
#                 "id": 500,
#                 "main": "Rain"
#             }
#         ],
#         "wind": {
#             "deg": 48,
#             "speed": 5.39
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 78
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -33.02,
#             "lon": 27.91
#         },
#         "dt": 1579910797,
#         "id": 1006984,
#         "main": {
#             "feels_like": 79.84,
#             "grnd_level": 1004,
#             "humidity": 75,
#             "pressure": 1008,
#             "sea_level": 1008,
#             "temp": 75.31,
#             "temp_max": 75.31,
#             "temp_min": 75.31
#         },
#         "name": "East London",
#         "sys": {
#             "country": "ZA",
#             "sunrise": 1579922640,
#             "sunset": 1579972604
#         },
#         "timezone": 7200,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04n",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 138,
#             "speed": 2.8
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 100
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 65.42,
#             "lon": -52.9
#         },
#         "dt": 1579910966,
#         "id": 3421982,
#         "main": {
#             "feels_like": -2.07,
#             "grnd_level": 985,
#             "humidity": 78,
#             "pressure": 994,
#             "sea_level": 994,
#             "temp": 10.96,
#             "temp_max": 10.96,
#             "temp_min": 10.96
#         },
#         "name": "Maniitsoq",
#         "snow": {
#             "3h": 0.13
#         },
#         "sys": {
#             "country": "GL",
#             "sunrise": 1579870229,
#             "sunset": 1579890980
#         },
#         "timezone": -10800,
#         "weather": [
#             {
#                 "description": "light snow",
#                 "icon": "13n",
#                 "id": 600,
#                 "main": "Snow"
#             }
#         ],
#         "wind": {
#             "deg": 114,
#             "speed": 12.41
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 100
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 20.93,
#             "lon": -17.03
#         },
#         "dt": 1579910966,
#         "id": 2377457,
#         "main": {
#             "feels_like": 55.83,
#             "humidity": 63,
#             "pressure": 1019,
#             "temp": 64.4,
#             "temp_max": 64.4,
#             "temp_min": 64.4
#         },
#         "name": "Nouadhibou",
#         "sys": {
#             "country": "MR",
#             "id": 2444,
#             "sunrise": 1579938406,
#             "sunset": 1579978412,
#             "type": 1
#         },
#         "timezone": 0,
#         "visibility": 8000,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04n",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 30,
#             "speed": 16.11
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 68
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -3.33,
#             "lon": 128.92
#         },
#         "dt": 1579910967,
#         "id": 1651591,
#         "main": {
#             "feels_like": 88.14,
#             "grnd_level": 1011,
#             "humidity": 74,
#             "pressure": 1012,
#             "sea_level": 1012,
#             "temp": 81.97,
#             "temp_max": 81.97,
#             "temp_min": 81.97
#         },
#         "name": "Amahai",
#         "sys": {
#             "country": "ID",
#             "sunrise": 1579901286,
#             "sunset": 1579945465
#         },
#         "timezone": 32400,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04d",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 349,
#             "speed": 5.26
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 90
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -35.02,
#             "lon": 117.89
#         },
#         "dt": 1579910967,
#         "id": 2077963,
#         "main": {
#             "feels_like": 62.71,
#             "humidity": 77,
#             "pressure": 1018,
#             "temp": 64.4,
#             "temp_max": 64.4,
#             "temp_min": 64.4
#         },
#         "name": "Albany",
#         "sys": {
#             "country": "AU",
#             "id": 9484,
#             "sunrise": 1579900773,
#             "sunset": 1579951274,
#             "type": 1
#         },
#         "timezone": 28800,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04d",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 310,
#             "speed": 6.93
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 75
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -42.88,
#             "lon": 147.33
#         },
#         "dt": 1579910783,
#         "id": 2163355,
#         "main": {
#             "feels_like": 54.79,
#             "humidity": 40,
#             "pressure": 1008,
#             "temp": 68.14,
#             "temp_max": 72,
#             "temp_min": 62.01
#         },
#         "name": "Hobart",
#         "sys": {
#             "country": "AU",
#             "id": 9545,
#             "sunrise": 1579892525,
#             "sunset": 1579945387,
#             "type": 1
#         },
#         "timezone": 39600,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04d",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 320,
#             "speed": 20.8
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 0
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -23.12,
#             "lon": -134.97
#         },
#         "dt": 1579910789,
#         "id": 4030556,
#         "main": {
#             "feels_like": 78.49,
#             "grnd_level": 1015,
#             "humidity": 76,
#             "pressure": 1015,
#             "sea_level": 1015,
#             "temp": 78.67,
#             "temp_max": 78.67,
#             "temp_min": 78.67
#         },
#         "name": "Rikitea",
#         "sys": {
#             "country": "PF",
#             "sunrise": 1579876415,
#             "sunset": 1579924194
#         },
#         "timezone": -32400,
#         "weather": [
#             {
#                 "description": "clear sky",
#                 "icon": "01d",
#                 "id": 800,
#                 "main": "Clear"
#             }
#         ],
#         "wind": {
#             "deg": 75,
#             "speed": 14.29
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 90
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 37.57,
#             "lon": 126.98
#         },
#         "dt": 1579910967,
#         "id": 1835848,
#         "main": {
#             "feels_like": 24.3,
#             "humidity": 75,
#             "pressure": 1030,
#             "temp": 30.22,
#             "temp_max": 32,
#             "temp_min": 28.4
#         },
#         "name": "Seoul",
#         "sys": {
#             "country": "KR",
#             "id": 5509,
#             "sunrise": 1579905690,
#             "sunset": 1579941992,
#             "type": 1
#         },
#         "timezone": 32400,
#         "visibility": 9000,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04d",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 30,
#             "speed": 2.24
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 100
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 62.23,
#             "lon": -6.59
#         },
#         "dt": 1579910721,
#         "id": 2618795,
#         "main": {
#             "feels_like": 27.75,
#             "humidity": 100,
#             "pressure": 1000,
#             "temp": 39.2,
#             "temp_max": 39.2,
#             "temp_min": 39.2
#         },
#         "name": "Klaksvik",
#         "sys": {
#             "country": "FO",
#             "id": 1596,
#             "sunrise": 1579943574,
#             "sunset": 1579968233,
#             "type": 1
#         },
#         "timezone": 0,
#         "visibility": 3200,
#         "weather": [
#             {
#                 "description": "light rain",
#                 "icon": "10n",
#                 "id": 500,
#                 "main": "Rain"
#             },
#             {
#                 "description": "mist",
#                 "icon": "50n",
#                 "id": 701,
#                 "main": "Mist"
#             }
#         ],
#         "wind": {
#             "deg": 140,
#             "speed": 16.11
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 90
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 41.05,
#             "lon": -0.13
#         },
#         "dt": 1579910968,
#         "id": 3130606,
#         "main": {
#             "feels_like": 35.74,
#             "humidity": 94,
#             "pressure": 1021,
#             "temp": 39,
#             "temp_max": 39,
#             "temp_min": 39
#         },
#         "name": "Alcaniz",
#         "sys": {
#             "country": "ES",
#             "id": 2008786,
#             "sunrise": 1579936671,
#             "sunset": 1579972035,
#             "type": 3
#         },
#         "timezone": 3600,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04n",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 193,
#             "gust": 3,
#             "speed": 1.01
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 1
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 35.87,
#             "lon": -101.97
#         },
#         "dt": 1579910968,
#         "id": 5520552,
#         "main": {
#             "feels_like": 46.08,
#             "humidity": 40,
#             "pressure": 1015,
#             "temp": 53.26,
#             "temp_max": 62.6,
#             "temp_min": 48
#         },
#         "name": "Dumas",
#         "sys": {
#             "country": "US",
#             "id": 3874,
#             "sunrise": 1579874028,
#             "sunset": 1579910739,
#             "type": 1
#         },
#         "timezone": -21600,
#         "visibility": 16093,
#         "weather": [
#             {
#                 "description": "clear sky",
#                 "icon": "01n",
#                 "id": 800,
#                 "main": "Clear"
#             }
#         ],
#         "wind": {
#             "deg": 210,
#             "speed": 5.82
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 40
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -33.93,
#             "lon": 18.42
#         },
#         "dt": 1579910780,
#         "id": 3369157,
#         "main": {
#             "feels_like": 64.58,
#             "humidity": 93,
#             "pressure": 1012,
#             "temp": 63.43,
#             "temp_max": 66.99,
#             "temp_min": 61
#         },
#         "name": "Cape Town",
#         "sys": {
#             "country": "ZA",
#             "id": 1899,
#             "sunrise": 1579924804,
#             "sunset": 1579974996,
#             "type": 1
#         },
#         "timezone": 7200,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "scattered clouds",
#                 "icon": "03n",
#                 "id": 802,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 340,
#             "speed": 4.7
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 12
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -37.62,
#             "lon": -73.65
#         },
#         "dt": 1579910797,
#         "id": 3883457,
#         "main": {
#             "feels_like": 52.18,
#             "grnd_level": 1000,
#             "humidity": 50,
#             "pressure": 1018,
#             "sea_level": 1018,
#             "temp": 60.96,
#             "temp_max": 60.96,
#             "temp_min": 60.96
#         },
#         "name": "Lebu",
#         "sys": {
#             "country": "CL",
#             "sunrise": 1579859954,
#             "sunset": 1579911217
#         },
#         "timezone": -10800,
#         "weather": [
#             {
#                 "description": "few clouds",
#                 "icon": "02d",
#                 "id": 801,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 191,
#             "speed": 12.44
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 100
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 51.32,
#             "lon": 42.77
#         },
#         "dt": 1579910813,
#         "id": 553766,
#         "main": {
#             "feels_like": 14.92,
#             "humidity": 93,
#             "pressure": 1004,
#             "temp": 30,
#             "temp_max": 30,
#             "temp_min": 30
#         },
#         "name": "Kamenka",
#         "snow": {
#             "3h": 1.56
#         },
#         "sys": {
#             "country": "RU",
#             "id": 2021293,
#             "sunrise": 1579928242,
#             "sunset": 1579959868,
#             "type": 3
#         },
#         "timezone": 10800,
#         "weather": [
#             {
#                 "description": "snow",
#                 "icon": "13n",
#                 "id": 601,
#                 "main": "Snow"
#             }
#         ],
#         "wind": {
#             "deg": 258,
#             "speed": 19.51
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 100
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 7.13,
#             "lon": 40.7
#         },
#         "dt": 1579910968,
#         "id": 336454,
#         "main": {
#             "feels_like": 58.35,
#             "grnd_level": 813,
#             "humidity": 60,
#             "pressure": 1014,
#             "sea_level": 1014,
#             "temp": 61.29,
#             "temp_max": 61.29,
#             "temp_min": 61.29
#         },
#         "name": "Ginir",
#         "sys": {
#             "country": "ET",
#             "sunrise": 1579923336,
#             "sunset": 1579965768
#         },
#         "timezone": 10800,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04n",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 296,
#             "speed": 4.12
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 75
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -22.97,
#             "lon": -42.03
#         },
#         "dt": 1579910793,
#         "id": 3471451,
#         "main": {
#             "feels_like": 74.39,
#             "humidity": 94,
#             "pressure": 1005,
#             "temp": 73.4,
#             "temp_max": 73.4,
#             "temp_min": 73.4
#         },
#         "name": "Arraial do Cabo",
#         "sys": {
#             "country": "BR",
#             "id": 8343,
#             "sunrise": 1579854114,
#             "sunset": 1579901877,
#             "type": 1
#         },
#         "timezone": -10800,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04n",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 261,
#             "speed": 13.24
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 75
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 62.46,
#             "lon": -114.35
#         },
#         "dt": 1579910668,
#         "id": 6185377,
#         "main": {
#             "feels_like": -7.04,
#             "humidity": 84,
#             "pressure": 1008,
#             "temp": 5,
#             "temp_max": 5,
#             "temp_min": 5
#         },
#         "name": "Yellowknife",
#         "sys": {
#             "country": "CA",
#             "id": 1007,
#             "sunrise": 1579883248,
#             "sunset": 1579907463,
#             "type": 1
#         },
#         "timezone": -25200,
#         "visibility": 24140,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04n",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 50,
#             "speed": 10.29
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 90
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 19.73,
#             "lon": -155.09
#         },
#         "dt": 1579910804,
#         "id": 5855927,
#         "main": {
#             "feels_like": 73.27,
#             "humidity": 61,
#             "pressure": 1018,
#             "temp": 74.01,
#             "temp_max": 80.6,
#             "temp_min": 68
#         },
#         "name": "Hilo",
#         "sys": {
#             "country": "US",
#             "id": 7881,
#             "sunrise": 1579885034,
#             "sunset": 1579925235,
#             "type": 1
#         },
#         "timezone": -36000,
#         "visibility": 16093,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04d",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 80,
#             "speed": 6.93
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 31
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -21.13,
#             "lon": 164.9
#         },
#         "dt": 1579910969,
#         "id": 2138592,
#         "main": {
#             "feels_like": 84.25,
#             "grnd_level": 977,
#             "humidity": 54,
#             "pressure": 1011,
#             "sea_level": 1011,
#             "temp": 82.63,
#             "temp_max": 82.63,
#             "temp_min": 82.63
#         },
#         "name": "Pouembout",
#         "rain": {
#             "3h": 0.31
#         },
#         "sys": {
#             "country": "NC",
#             "sunrise": 1579891053,
#             "sunset": 1579938424
#         },
#         "timezone": 39600,
#         "weather": [
#             {
#                 "description": "light rain",
#                 "icon": "10d",
#                 "id": 500,
#                 "main": "Rain"
#             }
#         ],
#         "wind": {
#             "deg": 68,
#             "speed": 5.97
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 100
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 64.28,
#             "lon": 100.25
#         },
#         "dt": 1579910817,
#         "id": 2014833,
#         "main": {
#             "feels_like": -17.46,
#             "grnd_level": 950,
#             "humidity": 97,
#             "pressure": 1007,
#             "sea_level": 1007,
#             "temp": -8.54,
#             "temp_max": -8.54,
#             "temp_min": -8.54
#         },
#         "name": "Tura",
#         "sys": {
#             "country": "RU",
#             "sunrise": 1579919052,
#             "sunset": 1579941463
#         },
#         "timezone": 25200,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04n",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 144,
#             "speed": 4.09
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 37
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 4.88,
#             "lon": -1.76
#         },
#         "dt": 1579910671,
#         "id": 2294915,
#         "main": {
#             "feels_like": 86.58,
#             "grnd_level": 1004,
#             "humidity": 88,
#             "pressure": 1012,
#             "sea_level": 1012,
#             "temp": 78.19,
#             "temp_max": 78.19,
#             "temp_min": 78.19
#         },
#         "name": "Takoradze",
#         "sys": {
#             "country": "GH",
#             "sunrise": 1579933339,
#             "sunset": 1579976149
#         },
#         "timezone": 0,
#         "weather": [
#             {
#                 "description": "scattered clouds",
#                 "icon": "03n",
#                 "id": 802,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 191,
#             "speed": 2.8
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 100
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 65.61,
#             "lon": -37.64
#         },
#         "dt": 1579910787,
#         "id": 3424607,
#         "main": {
#             "feels_like": 2.7,
#             "humidity": 45,
#             "pressure": 995,
#             "temp": 23,
#             "temp_max": 23,
#             "temp_min": 23
#         },
#         "name": "Tasiilaq",
#         "snow": {
#             "3h": 0.25
#         },
#         "sys": {
#             "country": "GL",
#             "id": 81,
#             "sunrise": 1579866706,
#             "sunset": 1579887177,
#             "type": 1
#         },
#         "timezone": -10800,
#         "weather": [
#             {
#                 "description": "light snow",
#                 "icon": "13n",
#                 "id": 600,
#                 "main": "Snow"
#             }
#         ],
#         "wind": {
#             "deg": 70,
#             "gust": 44.96,
#             "speed": 25.28
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 20
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 63.75,
#             "lon": -68.51
#         },
#         "dt": 1579910816,
#         "id": 5983720,
#         "main": {
#             "feels_like": -37.5,
#             "humidity": 67,
#             "pressure": 1016,
#             "temp": -25.29,
#             "temp_max": -25.01,
#             "temp_min": -25.6
#         },
#         "name": "Iqaluit",
#         "sys": {
#             "country": "CA",
#             "id": 797,
#             "sunrise": 1579872939,
#             "sunset": 1579895764,
#             "type": 1
#         },
#         "timezone": -18000,
#         "visibility": 24140,
#         "weather": [
#             {
#                 "description": "few clouds",
#                 "icon": "02n",
#                 "id": 801,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 310,
#             "speed": 9.17
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 83
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 6.62,
#             "lon": 73.07
#         },
#         "dt": 1579910969,
#         "id": 1337613,
#         "main": {
#             "feels_like": 87.94,
#             "grnd_level": 1010,
#             "humidity": 74,
#             "pressure": 1010,
#             "sea_level": 1010,
#             "temp": 81.46,
#             "temp_max": 81.46,
#             "temp_min": 81.46
#         },
#         "name": "Kulhudhuffushi",
#         "sys": {
#             "country": "MV",
#             "sunrise": 1579915523,
# ...
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 153,
#             "speed": 1.07
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 90
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -45.87,
#             "lon": 170.5
#         },
#         "dt": 1579910964,
#         "id": 2191562,
#         "main": {
#             "feels_like": 61.12,
#             "humidity": 79,
#             "pressure": 1014,
#             "temp": 66,
#             "temp_max": 66,
#             "temp_min": 66
#         },
#         "name": "Dunedin",
#         "sys": {
#             "country": "NZ",
#             "id": 75281,
#             "sunrise": 1579886417,
#             "sunset": 1579940372,
#             "type": 3
#         },
#         "timezone": 46800,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04d",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 213,
#             "gust": 15.99,
#             "speed": 14
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 97
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -20.1,
#             "lon": 146.27
#         },
#         "dt": 1579910802,
#         "id": 2171722,
#         "main": {
#             "feels_like": 90.84,
#             "grnd_level": 980,
#             "humidity": 59,
#             "pressure": 1011,
#             "sea_level": 1011,
#             "temp": 85.62,
#             "temp_max": 85.62,
#             "temp_min": 85.62
#         },
#         "name": "Charters Towers",
#         "sys": {
#             "country": "AU",
#             "sunrise": 1579895628,
#             "sunset": 1579942794
#         },
#         "timezone": 36000,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04d",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 9,
#             "speed": 3.96
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 40
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 69.49,
#             "lon": 88.4
#         },
#         "dt": 1579910796,
#         "id": 1490256,
#         "main": {
#             "feels_like": -8.9,
#             "humidity": 78,
#             "pressure": 988,
#             "temp": 8.6,
#             "temp_max": 8.6,
#             "temp_min": 8.6
#         },
#         "name": "Talnakh",
#         "sys": {
#             "country": "RU",
#             "id": 8951,
#             "sunrise": 1579926431,
#             "sunset": 1579939773,
#             "type": 1
#         },
#         "timezone": 25200,
#         "visibility": 9000,
#         "weather": [
#             {
#                 "description": "scattered clouds",
#                 "icon": "03n",
#                 "id": 802,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 150,
#             "speed": 20.13
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 8
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -16.7,
#             "lon": -151.02
#         },
#         "dt": 1579911034,
#         "id": 4034496,
#         "main": {
#             "feels_like": 84.78,
#             "grnd_level": 1011,
#             "humidity": 77,
#             "pressure": 1011,
#             "sea_level": 1011,
#             "temp": 82.2,
#             "temp_max": 82.2,
#             "temp_min": 82.2
#         },
#         "name": "Fare",
#         "sys": {
#             "country": "PF",
#             "sunrise": 1579880894,
#             "sunset": 1579927421
#         },
#         "timezone": -36000,
#         "weather": [
#             {
#                 "description": "clear sky",
#                 "icon": "01d",
#                 "id": 800,
#                 "main": "Clear"
#             }
#         ],
#         "wind": {
#             "deg": 85,
#             "speed": 13.04
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 100
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -7.71,
#             "lon": -66.98
#         },
#         "dt": 1579911034,
#         "id": 3662927,
#         "main": {
#             "feels_like": 83.5,
#             "grnd_level": 993,
#             "humidity": 98,
#             "pressure": 1009,
#             "sea_level": 1009,
#             "temp": 75.25,
#             "temp_max": 75.25,
#             "temp_min": 75.25
#         },
#         "name": "Pauini",
#         "rain": {
#             "3h": 1
#         },
#         "sys": {
#             "country": "BR",
#             "sunrise": 1579861519,
#             "sunset": 1579906450
#         },
#         "timezone": -14400,
#         "weather": [
#             {
#                 "description": "light rain",
#                 "icon": "10n",
#                 "id": 500,
#                 "main": "Rain"
#             }
#         ],
#         "wind": {
#             "deg": 333,
#             "speed": 3.38
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 31
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -19.55,
#             "lon": 169.27
#         },
#         "dt": 1579910803,
#         "id": 2136825,
#         "main": {
#             "feels_like": 82.13,
#             "grnd_level": 999,
#             "humidity": 79,
#             "pressure": 1009,
#             "sea_level": 1009,
#             "temp": 79.21,
#             "temp_max": 79.21,
#             "temp_min": 79.21
#         },
#         "name": "Isangel",
#         "rain": {
#             "3h": 0.25
#         },
#         "sys": {
#             "country": "VU",
#             "sunrise": 1579890158,
#             "sunset": 1579937221
#         },
#         "timezone": 39600,
#         "weather": [
#             {
#                 "description": "light rain",
#                 "icon": "10d",
#                 "id": 500,
#                 "main": "Rain"
#             }
#         ],
#         "wind": {
#             "deg": 115,
#             "speed": 10.33
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 90
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 58.81,
#             "lon": -122.7
#         },
#         "dt": 1579911034,
#         "id": 5955902,
#         "main": {
#             "feels_like": 2.48,
#             "humidity": 85,
#             "pressure": 1003,
#             "temp": 10.4,
#             "temp_max": 10.4,
#             "temp_min": 10.4
#         },
#         "name": "Fort Nelson",
#         "sys": {
#             "country": "CA",
#             "id": 986,
#             "sunrise": 1579883723,
#             "sunset": 1579910996,
#             "type": 1
#         },
#         "timezone": -25200,
#         "visibility": 8047,
#         "weather": [
#             {
#                 "description": "light snow",
#                 "icon": "13n",
#                 "id": 600,
#                 "main": "Snow"
#             }
#         ],
#         "wind": {
#             "deg": 292,
#             "speed": 3.47
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 90
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 40.52,
#             "lon": -111.94
#         },
#         "dt": 1579910947,
#         "id": 5780557,
#         "main": {
#             "feels_like": 31.77,
#             "humidity": 100,
#             "pressure": 1019,
#             "temp": 37.69,
#             "temp_max": 41,
#             "temp_min": 33.01
#         },
#         "name": "Riverton",
#         "sys": {
#             "country": "US",
#             "id": 6116,
#             "sunrise": 1579877057,
#             "sunset": 1579912497,
#             "type": 1
#         },
#         "timezone": -25200,
#         "visibility": 16093,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04d",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 140,
#             "speed": 5.82
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 3
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 14.55,
#             "lon": -60.84
#         },
#         "dt": 1579911035,
#         "id": 3570392,
#         "main": {
#             "feels_like": 84.13,
#             "humidity": 83,
#             "pressure": 1014,
#             "temp": 77.43,
#             "temp_max": 78.8,
#             "temp_min": 77
#         },
#         "name": "Le Vauclin",
#         "sys": {
#             "country": "MQ",
#             "id": 8779,
#             "sunrise": 1579861943,
#             "sunset": 1579903078,
#             "type": 1
#         },
#         "timezone": -14400,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "clear sky",
#                 "icon": "01n",
#                 "id": 800,
#                 "main": "Clear"
#             }
#         ],
#         "wind": {
#             "deg": 110,
#             "speed": 3.36
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 90
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 56.3,
#             "lon": 38.13
#         },
#         "dt": 1579911035,
#         "id": 496638,
#         "main": {
#             "feels_like": 25.47,
#             "humidity": 100,
#             "pressure": 996,
#             "temp": 33.8,
#             "temp_max": 33.8,
#             "temp_min": 33.8
#         },
#         "name": "Sergiyev Posad",
#         "sys": {
#             "country": "RU",
#             "id": 9027,
#             "sunrise": 1579930644,
#             "sunset": 1579959694,
#             "type": 1
#         },
#         "timezone": 10800,
#         "visibility": 9000,
#         "weather": [
#             {
#                 "description": "light rain",
#                 "icon": "10n",
#                 "id": 500,
#                 "main": "Rain"
#             },
#             {
#                 "description": "mist",
#                 "icon": "50n",
#                 "id": 701,
#                 "main": "Mist"
#             }
#         ],
#         "wind": {
#             "deg": 250,
#             "speed": 8.95
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 75
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 41.79,
#             "lon": -107.24
#         },
#         "dt": 1579911035,
#         "id": 5836068,
#         "main": {
#             "feels_like": 25.38,
#             "humidity": 69,
#             "pressure": 1016,
#             "temp": 33.8,
#             "temp_max": 33.8,
#             "temp_min": 33.8
#         },
#         "name": "Rawlins",
#         "sys": {
#             "country": "US",
#             "id": 5731,
#             "sunrise": 1579876120,
#             "sunset": 1579911177,
#             "type": 1
#         },
#         "timezone": -25200,
#         "visibility": 16093,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04d",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "speed": 6.93
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 0
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 49.03,
#             "lon": 104.08
#         },
#         "dt": 1579911035,
#         "id": 2031405,
#         "main": {
#             "feels_like": -6.11,
#             "grnd_level": 864,
#             "humidity": 67,
#             "pressure": 1033,
#             "sea_level": 1033,
#             "temp": 2.14,
#             "temp_max": 2.14,
#             "temp_min": 2.14
#         },
#         "name": "Erdenet",
#         "sys": {
#             "country": "MN",
#             "sunrise": 1579913050,
#             "sunset": 1579945626
#         },
#         "timezone": 28800,
#         "weather": [
#             {
#                 "description": "clear sky",
#                 "icon": "01n",
#                 "id": 800,
#                 "main": "Clear"
#             }
#         ],
#         "wind": {
#             "deg": 245,
#             "speed": 3.04
#         }
#     },
#     {
#         "base": "model",
#         "clouds": {
#             "all": 58
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 66.77,
#             "lon": 123.37
#         },
#         "dt": 1579911035,
#         "id": 2012530,
#         "main": {
#             "feels_like": -56.96,
#             "grnd_level": 1025,
#             "humidity": 96,
#             "pressure": 1031,
#             "sea_level": 1031,
#             "temp": -44.25,
#             "temp_max": -44.25,
#             "temp_min": -44.25
#         },
#         "name": "Zhigansk",
#         "sys": {
#             "country": "RU",
#             "sunrise": 1579915221,
#             "sunset": 1579934194
#         },
#         "timezone": 32400,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04n",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 159,
#             "speed": 9.91
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 75
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 60.45,
#             "lon": 26.23
#         },
#         "dt": 1579911035,
#         "id": 647572,
#         "main": {
#             "feels_like": 20.55,
#             "humidity": 92,
#             "pressure": 993,
#             "temp": 30.42,
#             "temp_max": 34,
#             "temp_min": 27
#         },
#         "name": "Loviisa",
#         "sys": {
#             "country": "FI",
#             "id": 1366,
#             "sunrise": 1579934934,
#             "sunset": 1579961116,
#             "type": 1
#         },
#         "timezone": 7200,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04n",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 240,
#             "speed": 10.29
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 75
#         },
#         "cod": 200,
#         "coord": {
#             "lat": -12.7,
#             "lon": -38.32
#         },
#         "dt": 1579910960,
#         "id": 3468031,
#         "main": {
#             "feels_like": 86.23,
#             "humidity": 78,
#             "pressure": 1012,
#             "temp": 82.4,
#             "temp_max": 82.4,
#             "temp_min": 82.4
#         },
#         "name": "Camacari",
#         "sys": {
#             "country": "BR",
#             "id": 8454,
#             "sunrise": 1579854201,
#             "sunset": 1579900009,
#             "type": 1
#         },
#         "timezone": -10800,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "broken clouds",
#                 "icon": "04n",
#                 "id": 803,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 30,
#             "speed": 11.41
#         }
#     },
#     {
#         "base": "stations",
#         "clouds": {
#             "all": 90
#         },
#         "cod": 200,
#         "coord": {
#             "lat": 60.93,
#             "lon": 76.55
#         },
#         "dt": 1579911035,
#         "id": 1497543,
#         "main": {
#             "feels_like": 5.13,
#             "humidity": 85,
#             "pressure": 993,
#             "temp": 15.8,
#             "temp_max": 15.8,
#             "temp_min": 15.8
#         },
#         "name": "Nizhnevartovsk",
#         "sys": {
#             "country": "RU",
#             "id": 8986,
#             "sunrise": 1579923073,
#             "sunset": 1579948819,
#             "type": 1
#         },
#         "timezone": 18000,
#         "visibility": 10000,
#         "weather": [
#             {
#                 "description": "overcast clouds",
#                 "icon": "04n",
#                 "id": 804,
#                 "main": "Clouds"
#             }
#         ],
#         "wind": {
#             "deg": 190,
#             "speed": 8.95
#         }
#     }
# ]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({
    "City" : city_data,
    "Country" : country_data,
    "Cloudiness" : cloudCover_data,
    "Date" : date_data,
    "Humidity" : humidity_data,
    "Lat" : lat_data,
    "Lng" : lng_data,
    "Temp" : temp_data,
    "Max Temp" : maxTemp_data,
    "Wind Speed" : windSpeed_data
})

# %%
# count the number of records in each column to make sure they all match
weather_df.count()
# Out:
# City          536
# Country       536
# Cloudiness    536
# Date          536
# Humidity      536
# Lat           536
# Lng           536
# Temp          536
# Max Temp      536
# Wind Speed    536
# dtype: int64

# %%
# show the top 5 rows of the data frame
weather_df.head()
# Out:
#           City Country  Cloudiness        Date  Humidity    Lat     Lng  \
# 0   Brookhaven      US           1  1579910962        44  31.58  -90.44
# 1    Upernavik      GL          85  1579910962        95  72.79  -56.15
# 2        Kimbe      PG          54  1579910963        66  -5.55  150.14
# 3  Bobrovytsya      UA         100  1579910963        69  50.75   31.38
# 4     Ust-Nera      RU          75  1579910963       100  64.57  143.20
#
#     Temp  Max Temp  Wind Speed
# 0  52.66     57.20        4.70
# 1 -14.37    -14.37        4.21
# 2  86.00     86.00        4.38
# 3  34.32     35.01        8.95
# 4 -47.87    -47.87        0.85

# %%
# export/save dataframe to csv file (to avoid potential issues later, using encoding="utf-8")
# weather_df.to_csv(output_data_file, encoding="utf-8", index=False)
weather_df.to_csv(f"{output_data_filepath}cities_weather.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Generate a scatter plot of Latitude vs. Temperature (max)

# create two lists of the data to be plotted on the scatter plot
# latVStemp_x_values = weather_df["Lat"].tolist()
latVStemp_x_values = weather_df.iloc[:,5]
# latVStemp_y_values = weather_df["Max Temp"].tolist()
latVStemp_y_values = weather_df.iloc[:,8]

# date_for_plot = datetime.datetime.fromtimestamp(min(weather_df["Date"])).strftime('%m/%d/%Y')
date_for_plot = datetime.datetime.fromtimestamp(sum(weather_df["Date"]) / len(weather_df["Date"])).strftime("%m/%d/%Y")

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(latVStemp_x_values,
            latVStemp_y_values,
#             color="blue",
            edgecolors='black'
           )
# plt.title(f"City Latitude vs. Max Temperature (xxDATExx)")
plt.title(f"City Latitude vs. Max Temperature ({date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# export/save figure to png file
plt.savefig(f"{output_data_filepath}latitude_vs_temp_plot.png")

plt.show()

# %%
# City Latitude vs. Temperature (max): what the code is and what is it analyzing?

# xxxxxxxxxxxxxxxxxxxxxxxxxxWRITEUPxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Generate a scatter plot of Latitude vs. Humidity

# create two lists of the data to be plotted on the scatter plot
latVShumidity_x_values = weather_df.iloc[:,5]
latVShumidity_y_values = weather_df.iloc[:,4]

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(latVShumidity_x_values,
            latVShumidity_y_values,
#             color="blue",
            edgecolors='black'
           )
plt.title(f"City Latitude vs. Humidity ({date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# export/save figure to png file
plt.savefig(f"{output_data_filepath}latitude_vs_humidity_plot.png")

plt.show()

# %%
# City Latitude vs. Humidity: what the code is and what is it analyzing?

# xxxxxxxxxxxxxxxxxxxxxxxxxxWRITEUPxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Generate a scatter plot of Latitude vs. Cloudiness

# create two lists of the data to be plotted on the scatter plot
latVScloudiness_x_values = weather_df.iloc[:,5]
latVScloudiness_y_values = weather_df.iloc[:,2]

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(latVScloudiness_x_values,
            latVScloudiness_y_values,
#             color="blue",
            edgecolors='black'
           )
plt.title(f"City Latitude vs. Cloudiness ({date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# export/save figure to png file
plt.savefig(f"{output_data_filepath}latitude_vs_cloudiness_plot.png")

plt.show()

# %%
# City Latitude vs. Cloudiness: what the code is and what is it analyzing?

# xxxxxxxxxxxxxxxxxxxxxxxxxxWRITEUPxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Generate a scatter plot of Latitude vs. Wind Speed

# create two lists of the data to be plotted on the scatter plot
latVSwindspeed_x_values = weather_df.iloc[:,5]
latVSwindspeed_y_values = weather_df.iloc[:,9]

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(latVSwindspeed_x_values,
            latVSwindspeed_y_values,
#             color="blue",
            edgecolors='black'
           )
plt.title(f"City Latitude vs. Wind Speed ({date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# export/save figure to png file
plt.savefig(f"{output_data_filepath}latitude_vs_wind_speed_plot.png")

plt.show()

# %%
# City Latitude vs. Wind Speed: what the code is and what is it analyzing?

# xxxxxxxxxxxxxxxxxxxxxxxxxxWRITEUPxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# ## Linear Regression

# %%
#### OPTIONAL: Create a function to create Linear Regression plots

# %%
# create function to calculate the linear regression plots and various other linregress() values
def lr_func(x_value, y_value):
    (slope_value, intercept_value, r_value, p_value, stderr_value) = linregress(x_value, y_value)
    line_eq_value = "y = " + str(round(slope_value,2)) + "x + " + str(round(intercept_value,2))
    regress_values = x_value * slope_value + intercept_value
#     return slope_value, intercept_value, r_value, p_value, stderr_value, line_eq_value, [regress_values]
    return {"slope_value": slope_value,
            "intercept_value": intercept_value,
            "r_value": r_value,
            "p_value": p_value,
            "stderr_value": stderr_value,
            "line_eq_value": line_eq_value,
            "regress_values": regress_values
    }

# %%
# # Generate a scatter plot of Latitude vs. Temperature (max)

# # create two lists of the data to be plotted on the scatter plot
# # latVStemp_x_values = weather_df["Lat"].tolist()
# latVStemp_x_values = weather_df.iloc[:,5]
# # latVStemp_y_values = weather_df["Max Temp"].tolist()
# latVStemp_y_values = weather_df.iloc[:,8]

# # date_for_plot = datetime.datetime.fromtimestamp(min(weather_df["Date"])).strftime('%m/%d/%Y')
# date_for_plot = datetime.datetime.fromtimestamp(sum(weather_df["Date"]) / len(weather_df["Date"])).strftime("%m/%d/%Y")

# # plot the scatter plot and set title and labels chart properties
# plt.figure(figsize=(8,6))
# plt.scatter(latVStemp_x_values,
#             latVStemp_y_values,
# #             color="blue",
#             edgecolors='black'
#            )
# # plt.title(f"City Latitude vs. Max Temperature (xxDATExx)")
# plt.title(f"City Latitude vs. Max Temperature ({date_for_plot})")
# plt.xlabel("Latitude")
# plt.ylabel("Max Temperature (F)")


# # Plot regression line
# plt.plot(latVStemp_x_values,latVStemp_regress_values,"r-")
# plt.annotate(latVStemp_line_eq,(6,10),fontsize=15,color="red")

# # Print r square value
# print(f"R squard: {round(latVStemp_rvalue,2)}")

# plt.show()

# %%
# create Northern and Southern Hemisphere data frames
n_hmsphr_wx_df = weather_df.loc[weather_df["Lat"] >= 0 ,:]
s_hmsphr_wx_df = weather_df.loc[weather_df["Lat"] < 0 ,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
n_latVStemp_x_values = n_hmsphr_wx_df.iloc[:,5]
n_latVStemp_y_values = n_hmsphr_wx_df.iloc[:,8]
n_latVStemp_r_value = lr_func(n_latVStemp_x_values, n_latVStemp_y_values)["r_value"]
n_latVStemp_on_plot_label_x_loc = min(n_latVStemp_x_values)
n_latVStemp_on_plot_label_y_loc = min(n_latVStemp_y_values)

# date_for_plot = datetime.datetime.fromtimestamp(min(weather_df["Date"])).strftime('%m/%d/%Y')
n_date_for_plot = datetime.datetime.fromtimestamp(sum(n_hmsphr_wx_df["Date"]) / len(n_hmsphr_wx_df["Date"])).strftime("%m/%d/%Y")

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(n_latVStemp_x_values,
            n_latVStemp_y_values,
#             color="blue",
            edgecolors='black'
           )
plt.title(f"Northern Hemisphere City Latitude vs. Max Temperature ({n_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# # Plot regression line
plt.plot(n_latVStemp_x_values,lr_func(n_latVStemp_x_values, n_latVStemp_y_values)["regress_values"],"r-")
# plt.annotate(lr_func(n_latVStemp_x_values, n_latVStemp_y_values)["line_eq_value"],(6,10),fontsize=12,color="red")
plt.annotate(lr_func(n_latVStemp_x_values, n_latVStemp_y_values)["line_eq_value"],
#              (6,10),
             (n_latVStemp_on_plot_label_x_loc ,n_latVStemp_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red")

# # Print r square value
# print(f"R squard: {round(latVStemp_rvalue,2)}")
print(f"The r-squared value is: {n_latVStemp_r_value}")
# plt.annotate(f"R^2 = {n_latVStemp_r_value.round(3)}",(6,0),fontsize=12,color="red")
plt.annotate(f"R^2 = {n_latVStemp_r_value.round(3)}",
#              (6,0),
             (n_latVStemp_on_plot_label_x_loc ,n_latVStemp_on_plot_label_y_loc),
             fontsize=12,
             color="red")

# export/save figure to png file
plt.savefig(f"{output_data_filepath}n_hemis_latitude_vs_temp_plot.png")

plt.show()
# Out:
# The r-squared value is: -0.8692136481204814

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
s_latVStemp_x_values = s_hmsphr_wx_df.iloc[:,5]
s_latVStemp_y_values = s_hmsphr_wx_df.iloc[:,8]
s_latVStemp_r_value = lr_func(s_latVStemp_x_values, s_latVStemp_y_values)["r_value"]
s_latVStemp_on_plot_label_x_loc = min(s_latVStemp_x_values)
s_latVStemp_on_plot_label_y_loc = min(s_latVStemp_y_values)

# date_for_plot = datetime.datetime.fromtimestamp(min(weather_df["Date"])).strftime('%m/%d/%Y')
s_date_for_plot = datetime.datetime.fromtimestamp(sum(s_hmsphr_wx_df["Date"]) / len(s_hmsphr_wx_df["Date"])).strftime("%m/%d/%Y")

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(s_latVStemp_x_values,
            s_latVStemp_y_values,
#             color="blue",
            edgecolors='black'
           )
plt.title(f"Southern Hemisphere City Latitude vs. Max Temperature ({s_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# # Plot regression line
plt.plot(s_latVStemp_x_values,lr_func(s_latVStemp_x_values, s_latVStemp_y_values)["regress_values"],"r-")
# plt.annotate(lr_func(s_latVStemp_x_values, s_latVStemp_y_values)["line_eq_value"],(6,10),fontsize=12,color="red")
plt.annotate(lr_func(s_latVStemp_x_values, s_latVStemp_y_values)["line_eq_value"],
             (s_latVStemp_on_plot_label_x_loc ,s_latVStemp_on_plot_label_y_loc + 3.5),
             fontsize=12,
             color="red")

# # Print r square value
# print(f"R squard: {round(latVStemp_rvalue,2)}")
print(f"The r-squared value is: {s_latVStemp_r_value}")
# plt.annotate(f"R^2 = {s_latVStemp_r_value.round(3)}",(6,0),fontsize=12,color="red")
plt.annotate(f"R^2 = {s_latVStemp_r_value.round(3)}",
             (s_latVStemp_on_plot_label_x_loc ,s_latVStemp_on_plot_label_y_loc),
             fontsize=12,
             color="red")

# export/save figure to png file
plt.savefig(f"{output_data_filepath}s_hemis_latitude_vs_temp_plot.png")

plt.show()
# Out:
# The r-squared value is: 0.40079658553085884

# %%
# Northern/Southern Hemisphere City Latitude vs. Temperature (max):
# explain what the linear regression is modelling such as any relationships you notice and any other analysis you may have

# xxxxxxxxxxxxxxxxxxxxxxxxxxWRITEUPxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
n_latVShumidity_x_values = n_hmsphr_wx_df.iloc[:,5]
n_latVShumidity_y_values = n_hmsphr_wx_df.iloc[:,4]
n_latVShumidity_r_value = lr_func(n_latVShumidity_x_values, n_latVShumidity_y_values)["r_value"]
n_latVShumidity_on_plot_label_x_loc = min(n_latVShumidity_x_values)
n_latVShumidity_on_plot_label_y_loc = min(n_latVShumidity_y_values)

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(n_latVShumidity_x_values,
            n_latVShumidity_y_values,
            edgecolors='black'
           )
plt.title(f"Northern Hemisphere City Latitude vs. Humidity ({n_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Plot regression line
plt.plot(n_latVShumidity_x_values,lr_func(n_latVShumidity_x_values, n_latVShumidity_y_values)["regress_values"],"r-")
plt.annotate(lr_func(n_latVShumidity_x_values, n_latVShumidity_y_values)["line_eq_value"],
             (n_latVShumidity_on_plot_label_x_loc ,n_latVShumidity_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red"
             )

# Print r square value
print(f"The r-squared value is: {n_latVShumidity_r_value}")
plt.annotate(f"R^2 = {n_latVShumidity_r_value.round(3)}",
             (n_latVShumidity_on_plot_label_x_loc ,n_latVShumidity_on_plot_label_y_loc),
             fontsize=12,
             color="red"
             )

# export/save figure to png file
plt.savefig(f"{output_data_filepath}n_hemis_latitude_vs_humidity_plot.png")

plt.show()
# Out:
# The r-squared value is: 0.3767855131596288

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
s_latVShumidity_x_values = s_hmsphr_wx_df.iloc[:,5]
s_latVShumidity_y_values = s_hmsphr_wx_df.iloc[:,4]
s_latVShumidity_r_value = lr_func(s_latVShumidity_x_values, s_latVShumidity_y_values)["r_value"]
s_latVShumidity_on_plot_label_x_loc = min(s_latVShumidity_x_values)
s_latVShumidity_on_plot_label_y_loc = min(s_latVShumidity_y_values)

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(s_latVShumidity_x_values,
            s_latVShumidity_y_values,
            edgecolors='black'
           )
plt.title(f"Southern Hemisphere City Latitude vs. Humidity ({s_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Plot regression line
plt.plot(s_latVShumidity_x_values,lr_func(s_latVShumidity_x_values, s_latVShumidity_y_values)["regress_values"],"r-")
plt.annotate(lr_func(s_latVShumidity_x_values, s_latVShumidity_y_values)["line_eq_value"],
             (s_latVShumidity_on_plot_label_x_loc ,s_latVShumidity_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red"
             )

# Print r square value
print(f"The r-squared value is: {s_latVShumidity_r_value}")
plt.annotate(f"R^2 = {s_latVShumidity_r_value.round(3)}",
             (s_latVShumidity_on_plot_label_x_loc ,s_latVShumidity_on_plot_label_y_loc),
             fontsize=12,
             color="red"
             )

# export/save figure to png file
plt.savefig(f"{output_data_filepath}s_hemis_latitude_vs_humidity_plot.png")

plt.show()
# Out:
# The r-squared value is: 0.29337768628073524

# %%
# Northern/Southern Hemisphere City Latitude vs. Temperature (max):
# explain what the linear regression is modelling such as any relationships you notice and any other analysis you may have

# xxxxxxxxxxxxxxxxxxxxxxxxxxWRITEUPxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
n_latVScloudiness_x_values = n_hmsphr_wx_df.iloc[:,5]
n_latVScloudiness_y_values = n_hmsphr_wx_df.iloc[:,2]
n_latVScloudiness_r_value = lr_func(n_latVScloudiness_x_values, n_latVScloudiness_y_values)["r_value"]
n_latVScloudiness_on_plot_label_x_loc = min(n_latVScloudiness_x_values)
n_latVScloudiness_on_plot_label_y_loc = min(n_latVScloudiness_y_values)

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(n_latVScloudiness_x_values,
            n_latVScloudiness_y_values,
            edgecolors='black'
           )
plt.title(f"Northern Hemisphere City Latitude vs. Cloudiness ({n_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Plot regression line
plt.plot(n_latVScloudiness_x_values,lr_func(n_latVScloudiness_x_values, n_latVScloudiness_y_values)["regress_values"],"r-")
plt.annotate(lr_func(n_latVScloudiness_x_values, n_latVScloudiness_y_values)["line_eq_value"],
             (n_latVScloudiness_on_plot_label_x_loc ,n_latVScloudiness_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red"
             )

# Print r square value
print(f"The r-squared value is: {n_latVScloudiness_r_value}")
plt.annotate(f"R^2 = {n_latVScloudiness_r_value.round(3)}",
             (n_latVScloudiness_on_plot_label_x_loc ,n_latVScloudiness_on_plot_label_y_loc),
             fontsize=12,
             color="red"
             )

# export/save figure to png file
plt.savefig(f"{output_data_filepath}n_hemis_latitude_vs_cloudiness_plot.png")

plt.show()
# Out:
# The r-squared value is: 0.18171258794054068

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
s_latVScloudiness_x_values = s_hmsphr_wx_df.iloc[:,5]
s_latVScloudiness_y_values = s_hmsphr_wx_df.iloc[:,2]
s_latVScloudiness_r_value = lr_func(s_latVScloudiness_x_values, s_latVScloudiness_y_values)["r_value"]
s_latVScloudiness_on_plot_label_x_loc = min(s_latVScloudiness_x_values)
s_latVScloudiness_on_plot_label_y_loc = min(s_latVScloudiness_y_values)

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(s_latVScloudiness_x_values,
            s_latVScloudiness_y_values,
            edgecolors='black'
           )
plt.title(f"Southern Hemisphere City Latitude vs. Cloudiness ({s_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Plot regression line
plt.plot(s_latVScloudiness_x_values,lr_func(s_latVScloudiness_x_values, s_latVScloudiness_y_values)["regress_values"],"r-")
plt.annotate(lr_func(s_latVScloudiness_x_values, s_latVScloudiness_y_values)["line_eq_value"],
             (s_latVScloudiness_on_plot_label_x_loc ,s_latVScloudiness_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red"
             )

# Print r square value
print(f"The r-squared value is: {s_latVScloudiness_r_value}")
plt.annotate(f"R^2 = {s_latVScloudiness_r_value.round(3)}",
             (s_latVScloudiness_on_plot_label_x_loc ,s_latVScloudiness_on_plot_label_y_loc),
             fontsize=12,
             color="red"
             )

# export/save figure to png file
plt.savefig(f"{output_data_filepath}s_hemis_latitude_vs_cloudiness_plot.png")

plt.show()
# Out:
# The r-squared value is: 0.19176144305585066

# %%
# Northern/Southern Hemisphere City Latitude vs. Temperature (max):
# explain what the linear regression is modelling such as any relationships you notice and any other analysis you may have

# xxxxxxxxxxxxxxxxxxxxxxxxxxWRITEUPxxxxxxxxxxxxxxxxxxxxxxxxxx

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
n_latVSwindspeed_x_values = n_hmsphr_wx_df.iloc[:,5]
n_latVSwindspeed_y_values = n_hmsphr_wx_df.iloc[:,9]
n_latVSwindspeed_r_value = lr_func(n_latVSwindspeed_x_values, n_latVSwindspeed_y_values)["r_value"]
n_latVSwindspeed_on_plot_label_x_loc = min(n_latVSwindspeed_x_values)
n_latVSwindspeed_on_plot_label_y_loc = min(n_latVSwindspeed_y_values)

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(n_latVSwindspeed_x_values,
            n_latVSwindspeed_y_values,
            edgecolors='black'
           )
plt.title(f"Northern Hemisphere City Latitude vs. Wind Speed ({n_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Plot regression line
plt.plot(n_latVSwindspeed_x_values,lr_func(n_latVSwindspeed_x_values, n_latVSwindspeed_y_values)["regress_values"],"r-")
plt.annotate(lr_func(n_latVSwindspeed_x_values, n_latVSwindspeed_y_values)["line_eq_value"],
             (n_latVSwindspeed_on_plot_label_x_loc ,n_latVSwindspeed_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red"
             )

# Print r square value
print(f"The r-squared value is: {n_latVSwindspeed_r_value}")
plt.annotate(f"R^2 = {n_latVSwindspeed_r_value.round(3)}",
             (n_latVSwindspeed_on_plot_label_x_loc ,n_latVSwindspeed_on_plot_label_y_loc),
             fontsize=12,
             color="red"
             )

# export/save figure to png file
plt.savefig(f"{output_data_filepath}n_hemis_latitude_vs_windspeed_plot.png")

plt.show()
# Out:
# The r-squared value is: 0.08844846946307258

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# create lists of the data to be plotted on the scatter plot
s_latVSwindspeed_x_values = s_hmsphr_wx_df.iloc[:,5]
s_latVSwindspeed_y_values = s_hmsphr_wx_df.iloc[:,9]
s_latVSwindspeed_r_value = lr_func(s_latVSwindspeed_x_values, s_latVSwindspeed_y_values)["r_value"]
s_latVSwindspeed_on_plot_label_x_loc = min(s_latVSwindspeed_x_values)
s_latVSwindspeed_on_plot_label_y_loc = min(s_latVSwindspeed_y_values)

# plot the scatter plot and set title and labels chart properties
plt.figure(figsize=(8,6))
plt.scatter(s_latVSwindspeed_x_values,
            s_latVSwindspeed_y_values,
            edgecolors='black'
           )
plt.title(f"Southern Hemisphere City Latitude vs. Wind Speed ({s_date_for_plot})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Plot regression line
plt.plot(s_latVSwindspeed_x_values,lr_func(s_latVSwindspeed_x_values, s_latVSwindspeed_y_values)["regress_values"],"r-")
plt.annotate(lr_func(s_latVSwindspeed_x_values, s_latVSwindspeed_y_values)["line_eq_value"],
             (s_latVSwindspeed_on_plot_label_x_loc ,s_latVSwindspeed_on_plot_label_y_loc + 10),
             fontsize=12,
             color="red"
             )

# Print r square value
print(f"The r-squared value is: {s_latVSwindspeed_r_value}")
plt.annotate(f"R^2 = {s_latVSwindspeed_r_value.round(3)}",
             (s_latVSwindspeed_on_plot_label_x_loc ,s_latVSwindspeed_on_plot_label_y_loc),
             fontsize=12,
             color="red"
             )

# export/save figure to png file
plt.savefig(f"{output_data_filepath}s_hemis_latitude_vs_windspeed_plot.png")

plt.show()
# Out:
# The r-squared value is: -0.31619258964505187

# %%
# Northern/Southern Hemisphere City Latitude vs. Temperature (max):
# explain what the linear regression is modelling such as any relationships you notice and any other analysis you may have

# xxxxxxxxxxxxxxxxxxxxxxxxxxWRITEUPxxxxxxxxxxxxxxxxxxxxxxxxxx
